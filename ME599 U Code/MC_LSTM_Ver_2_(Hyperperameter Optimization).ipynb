# %% [markdown]
# **MC-LSTM**

# %%
## Run this so that the Original Code can pull and clone the Github repository and install it
# !git clone https://github.com/zexyang/RUL_prediction_ME599.git
# %cd RUL_prediction_ME599
# !cat README.md
# !pip install keras-tuner
# Out:
# Cloning into 'RUL_prediction_ME599'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 73 (delta 22), reused 26 (delta 8), pack-reused 18
# Receiving objects: 100% (73/73), 63.94 MiB | 7.89 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Updating files: 100% (34/34), done.
# /content/RUL_prediction_ME599
# # A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data
# [![DOI:10.1145/3575882.3575903](http://img.shields.io/badge/DOI-10.1145/3575882.3575903-1481c1.svg)](https://doi.org/10.1145/3575882.3575903)
#
# + Battery RUL prediction using data-driven method based on a hybrid deep model of Convolutional Neural Networks (CNN) and Long-Short Term Memory (LSTM).
# + CNN and LSTM are used to extract features from multiple measurable data (Voltage, Current, Temperature, Capacity) in parallel.
# + CNN extracts features of multi-channel charging profiles, whereas LSTM extracts features of historical capacity data of discharging profiles which related to time dependency.
# + This repository provides the code for training in python.
# ---
# ### Framework:
# ![Contoh Gambar](framework.png)
# + Voltage (V), Current (I), and Temperature (T) inputs will each get in the CNN layer separately.
#   + Feature V gets into a different CNN layer with features I and T, as well as a feature I get into a separate CNN layer with V
#   and T, and so on.
#   + The output from the CNN layer for each feature, is then concatenated. Then they get the next CNN layer
#   + The extracted features in the last CNN layer is concatenated with the output of the LSTM layer.
#
# ### Results
# ![Contoh Gambar](result.png)
#
# | Model        |  RMSE  |   MAE  | MAPE (%) |
# |--------------|:------:|:------:|:--------:|
# | SC-LSTM      | 0,0620 | 0,0549 |  3,6080  |
# | MC-LSTM      | 0,0403 | 0,0340 |  2,2847  |
# | SC-CNN-LSTM  | 0,0270 | 0,0215 |  1,3804  |
# | MC-CNN-LSTM  | 0,0359 | 0,0291 |  1,9346  |
# | MC-SCNN-LSTM | 0,0276 | 0,0220 |  1,4207  |
#
# + SC : Single Channel, MC : Multi Channel
# + The performance of prediction models were compared  using some evaluation metrics
# including root mean square error (RMSE), mean absolute error
# (MAE), and mean absolute percentage error (MAPE).
# + The hybrid model with excellent feature extraction helps to produce more accurate prediction.
# + The MC-SCNNLSTM, MC-CNN-LSTM, and SC-CNN-LSTM model’s prediction results produce predictive values that are close to actual values and are better than the baseline model.
# + Hybrid  of CNN-LSTM model achieves 61%, 37%, and 15% performance
# improvements of MAPE in terms of SC-CNN-LSTM, MC-SCNN-LSTM, and MC-CNN-LSTM respectively, compared to using the single model
#
#
# ### How to Cite
#
# ```
#   @inproceedings{10.1145/3575882.3575903,
#   author = {Hafizhahullah, Huzaifi and Yuliani, Asri Rizki and Pardede, Hilman and Ramdan, Ade and Zilvan, Vicky and Krisnandi, Dikdik and Kadar, Jimmy},
#   title = {A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data},
#   year = {2023},
#   isbn = {9781450397902},
#   publisher = {Association for Computing Machinery},
#   url = {https://doi.org/10.1145/3575882.3575903},
#   doi = {10.1145/3575882.3575903},
#   booktitle = {Proceedings of the 2022 International Conference on Computer, Control, Informatics and Its Applications},
#   pages = {106–110},
#   numpages = {5},
#   keywords = {Lithium-ion battery, remaining useful life, capacity prediction, CNN-LSTM, neural networks},
#   }
# ```Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.2.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import os
import re
import json
import numpy as np
import random as rn
import tensorflow as tf
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Set seeds for reproducibility
SEED = 12345
os.environ["CUDA_VISIBLE_DEVICES"] = str(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
rn.seed(SEED)
tf.compat.v1.random.set_random_seed(SEED)
tf.random.set_seed(SEED)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# Define preprocessing function
def preprocess(dataset):
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(dataset)
    return scaled, scaler

# Define function to extract VIT capacity
def extract_VIT_capacity(x_datasets, y_datasets, seq_len, hop, sample):
    from pandas import read_csv
    V, I, T, C = [], [], [], []
    x, y = [], []

    for x_data, y_data in zip(x_datasets, y_datasets):
        x_df = read_csv(x_data).dropna()[['cycle', 'voltage_battery', 'current_battery', 'temp_battery']]
        x_df = x_df[x_df['cycle'] != 0].reset_index(drop=True)

        y_df = read_csv(y_data).dropna()[['capacity']]
        y_df['cycle_idx'] = y_df.index + 1
        y_df = y_df.astype('float32').values

        data_len = int(np.floor((len(y_df) - seq_len - 1) / hop)) + 1

        for i in range(len(y_df)):
            cy = x_df.cycle.unique()[i]
            df = x_df[x_df['cycle'] == cy]
            cap = np.array([y_df[i, 0]])
            C.append(cap)
            scaled_C, scaler_C = preprocess(np.array(C))
            le = len(df['voltage_battery']) % sample

            vTemp = df['voltage_battery'].to_numpy()
            if le != 0:
                vTemp = vTemp[0:-le]
            vTemp = np.reshape(vTemp, (len(vTemp) // sample, -1), order="F").mean(axis=0)
            V.append(vTemp)
            scaled_V, _ = preprocess(np.array(V))

            iTemp = df['current_battery'].to_numpy()
            if le != 0:
                iTemp = iTemp[0:-le]
            iTemp = np.reshape(iTemp, (len(iTemp) // sample, -1), order="F").mean(axis=0)
            I.append(iTemp)
            scaled_I, _ = preprocess(np.array(I))

            tTemp = df['temp_battery'].to_numpy()
            if le != 0:
                tTemp = tTemp[0:-le]
            tTemp = np.reshape(tTemp, (len(tTemp) // sample, -1), order="F").mean(axis=0)
            T.append(tTemp)
            scaled_T, _ = preprocess(np.array(T))

            VIT_temp = np.concatenate([scaled_V, scaled_I, scaled_T, scaled_C], axis=1)

        for i in range(data_len):
            x.append(VIT_temp[(hop * i):(hop * i + seq_len)])
            y.append(scaled_C[hop * i + seq_len])

    return np.array(x), np.array(y), scaler_C

# Define main function
def main():
    import RUL_prediction_ME599.train.param_VITC_C as pr
    import RUL_prediction_ME599.train.utils as utils

    pth = pr.pth
    train_x_files = [os.path.join(pth, 'charge/train', f) for f in os.listdir(os.path.join(pth, 'charge/train'))]
    train_x_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    train_y_files = [os.path.join(pth, 'discharge/train', f) for f in os.listdir(os.path.join(pth, 'discharge/train'))]
    train_y_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    test_x_data = [os.path.join(pth, 'charge/test', f) for f in os.listdir(os.path.join(pth, 'charge/test'))]
    test_y_data = [os.path.join(pth, 'discharge/test', f) for f in os.listdir(os.path.join(pth, 'discharge/test'))]

    accuracy_results = {}

    learning_rate_space = np.logspace(np.log10(1e-6), np.log10(1e-2), 10000)
    dropout_space = np.linspace(.25, .75, 10000)
    activation_space = ["relu", "tanh"]

    lowest_error = np.inf

    for _ in range(1000):

        learning_rate = np.random.choice(learning_rate_space)
        dropout_rate = np.random.choice(dropout_space)
        lstm_activation = np.random.choice(activation_space)
        dense_activation = np.random.choice(activation_space)


        folds = list(KFold(n_splits=pr.k, shuffle=True, random_state=pr.random).split(train_x_files))

        fold_accuracies = []

        for j, (train_idx, val_idx) in enumerate(folds):
            # print('\nFold', j + 1)
            train_x_data = [train_x_files[i] for i in train_idx]
            train_y_data = [train_y_files[i] for i in train_idx]
            val_x_data = [train_x_files[i] for i in val_idx]
            val_y_data = [train_y_files[i] for i in val_idx]

            trainX, trainY, SS_tr = extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len, pr.hop, pr.sample)
            valX, valY, SS_val = extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len, pr.hop, pr.sample)
            testX, testY, SS_tt = extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len, pr.hop, pr.sample)

            # print('Input shape: {}'.format(trainX.shape))

            model = Sequential([
                    LSTM(400, input_shape=(pr.seq_len, trainX.shape[-1]), activation=lstm_activation, return_sequences=True),
                    Dropout(dropout_rate),
                    LSTM(400, return_sequences=False),
                    Dense(128, activation=dense_activation),
                    Dense(1)
            ])

            model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

            model.summary()

            history = model.fit(trainX, trainY, validation_data=(valX, valY), batch_size=pr.batch_size, epochs=pr.epochs)

            val_results = model.evaluate(valX, valY)
            # print('Val loss:', val_results)

            valPredict = model.predict(valX)
            inv_valY = SS_val.inverse_transform(valY)
            inv_valPredict = SS_val.inverse_transform(valPredict)

            val_mae = mean_absolute_error(inv_valY, inv_valPredict)
            val_rmse = np.sqrt(mean_squared_error(inv_valY, inv_valPredict))
            fold_accuracies.append(val_rmse)

            # model_dir = pr.model_dir + f'_k{j + 1}_lstm{lstm_units}'
            # save_dir = pr.save_dir
            # os.makedirs(os.path.join(save_dir, model_dir), exist_ok=True)

            # model.save(os.path.join(save_dir, model_dir, "saved_model_and_weight"))
            # print("Model and weights saved.")

        accuracy_results = np.mean(fold_accuracies)
        if accuracy_results < lowest_error:
            lowest_error = accuracy_results
            best_learning_rate = learning_rate
            best_dropout_rate = dropout_rate
            best_lstm_activation = lstm_activation
            best_dense_activation = dense_activation

        # print(f'Average RMSE for {lstm_units} LSTM units: {accuracy_results[lstm_units]}')
    print(f"New lowest error achieved: {lowest_error}")
    print(f"Learning Rate: {best_learning_rate}")
    print(f"Dropout Rate: {best_dropout_rate}")
    print(f"LSTM Activation: {best_lstm_activation}")
    print(f"Dense Activation: {best_dense_activation}")
    # Plotting LSTM units vs. accuracy
    # plt.figure(figsize=(10, 6))
    # lstm_units = list(accuracy_results.keys())
    # accuracies = list(accuracy_results.values())
    # plt.plot(lstm_units, accuracies, marker='o')
    # plt.xlabel('Number of LSTM units')
    # plt.ylabel('Validation RMSE')
    # plt.title('LSTM units vs. Validation RMSE')
    # plt.grid(True)
    # plt.show()

if __name__ == "__main__":
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 400)            691200
#
#  dropout (Dropout)           (None, 5, 400)            0
#
#  lstm_1 (LSTM)               (None, 400)               1281600
#
#  dense (Dense)               (None, 128)               51328
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 6s 172ms/step - loss: 0.1364 - val_loss: 0.1250
# Epoch 2/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0696 - val_loss: 0.0992
# Epoch 3/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0520 - val_loss: 0.0709
# Epoch 4/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0298 - val_loss: 0.0525
# Epoch 5/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0194 - val_loss: 0.0390
# Epoch 6/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0144 - val_loss: 0.0350
# Epoch 7/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0123 - val_loss: 0.0289
# Epoch 8/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0089 - val_loss: 0.0255
# Epoch 9/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0067 - val_loss: 0.0248
# Epoch 10/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0056 - val_loss: 0.0205
# Epoch 11/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0047 - val_loss: 0.0187
# Epoch 12/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0043 - val_loss: 0.0154
# Epoch 13/100
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0037 - val_loss: 0.0142
# Epoch 14/100
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0029 - val_loss: 0.0122
# Epoch 15/100
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0033 - val_loss: 0.0117
# Epoch 16/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0028 - val_loss: 0.0109
# Epoch 17/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0031 - val_loss: 0.0112
# Epoch 18/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0031 - val_loss: 0.0113
# Epoch 19/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0028 - val_loss: 0.0106
# Epoch 20/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0029 - val_loss: 0.0110
# Epoch 21/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0028 - val_loss: 0.0107
# Epoch 22/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0029 - val_loss: 0.0108
# Epoch 23/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0026 - val_loss: 0.0106
# Epoch 24/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0029 - val_loss: 0.0104
# Epoch 25/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 26/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0029 - val_loss: 0.0099
# Epoch 27/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0027 - val_loss: 0.0105
# Epoch 28/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 29/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0027 - val_loss: 0.0101
# Epoch 30/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 31/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0023 - val_loss: 0.0100
# Epoch 32/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0025 - val_loss: 0.0107
# Epoch 33/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0022 - val_loss: 0.0104
# Epoch 34/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 35/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0022 - val_loss: 0.0105
# Epoch 36/100
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0022 - val_loss: 0.0106
# Epoch 37/100
# 7/7 [==============================] - 1s 171ms/step - loss: 0.0022 - val_loss: 0.0104
# Epoch 38/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 39/100
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 40/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0024 - val_loss: 0.0101
# Epoch 41/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 42/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 43/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 44/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 45/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0018 - val_loss: 0.0101
# Epoch 46/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0018 - val_loss: 0.0101
# Epoch 47/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0017 - val_loss: 0.0102
# Epoch 48/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0017 - val_loss: 0.0096
# Epoch 49/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0018 - val_loss: 0.0101
# Epoch 50/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0019 - val_loss: 0.0107
# Epoch 51/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0020 - val_loss: 0.0105
# Epoch 52/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0018 - val_loss: 0.0099
# Epoch 53/100
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 54/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0018 - val_loss: 0.0101
# Epoch 55/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0018 - val_loss: 0.0103
# Epoch 56/100
# 7/7 [==============================] - 1s 141ms/step - loss: 0.0017 - val_loss: 0.0100
# Epoch 57/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0017 - val_loss: 0.0097
# Epoch 58/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0017 - val_loss: 0.0099
# Epoch 59/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0019 - val_loss: 0.0101
# Epoch 60/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0018 - val_loss: 0.0103
# Epoch 61/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0016 - val_loss: 0.0099
# Epoch 62/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0014 - val_loss: 0.0097
# Epoch 63/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0015 - val_loss: 0.0098
# Epoch 64/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0017 - val_loss: 0.0096
# Epoch 65/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0018 - val_loss: 0.0100
# Epoch 66/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0017 - val_loss: 0.0090
# Epoch 67/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0016 - val_loss: 0.0095
# Epoch 68/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0018 - val_loss: 0.0097
# Epoch 69/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0015 - val_loss: 0.0098
# Epoch 70/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0015 - val_loss: 0.0098
# Epoch 71/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0014 - val_loss: 0.0099
# Epoch 72/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0016 - val_loss: 0.0097
# Epoch 73/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0015 - val_loss: 0.0100
# Epoch 74/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0016 - val_loss: 0.0098
# Epoch 75/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0014 - val_loss: 0.0092
# Epoch 76/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0015 - val_loss: 0.0094
# Epoch 77/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0015 - val_loss: 0.0097
# Epoch 78/100
# 7/7 [==============================] - 1s 111ms/step - loss: 0.0015 - val_loss: 0.0096
# Epoch 79/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0015 - val_loss: 0.0102
# Epoch 80/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0013 - val_loss: 0.0096
# Epoch 81/100
# 7/7 [==============================] - 1s 141ms/step - loss: 0.0014 - val_loss: 0.0094
# Epoch 82/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0014 - val_loss: 0.0095
# Epoch 83/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0015 - val_loss: 0.0101
# Epoch 84/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0015 - val_loss: 0.0100
# Epoch 85/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0013 - val_loss: 0.0096
# Epoch 86/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0014 - val_loss: 0.0099
# Epoch 87/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0013 - val_loss: 0.0093
# Epoch 88/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0014 - val_loss: 0.0100
# Epoch 89/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0106
# Epoch 90/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0014 - val_loss: 0.0099
# Epoch 91/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0014 - val_loss: 0.0100
# Epoch 92/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0015 - val_loss: 0.0098
# Epoch 93/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0014 - val_loss: 0.0101
# Epoch 94/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0015 - val_loss: 0.0101
# Epoch 95/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0014 - val_loss: 0.0094
# Epoch 96/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0012 - val_loss: 0.0102
# Epoch 97/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0103
# Epoch 98/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0013 - val_loss: 0.0100
# Epoch 99/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0012 - val_loss: 0.0095
# Epoch 100/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0013 - val_loss: 0.0097
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0097
# 6/6 [==============================] - 1s 12ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 400)            691200
#
#  dropout_1 (Dropout)         (None, 5, 400)            0
#
#  lstm_3 (LSTM)               (None, 400)               1281600
#
#  dense_2 (Dense)             (None, 128)               51328
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 4s 167ms/step - loss: 0.2284 - val_loss: 0.1482
# Epoch 2/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0845 - val_loss: 0.0881
# Epoch 3/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0696 - val_loss: 0.0723
# Epoch 4/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0505 - val_loss: 0.0548
# Epoch 5/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0351 - val_loss: 0.0465
# Epoch 6/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0281 - val_loss: 0.0359
# Epoch 7/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0242 - val_loss: 0.0290
# Epoch 8/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0205 - val_loss: 0.0261
# Epoch 9/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0168 - val_loss: 0.0240
# Epoch 10/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0129 - val_loss: 0.0206
# Epoch 11/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0099 - val_loss: 0.0186
# Epoch 12/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0076 - val_loss: 0.0156
# Epoch 13/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.0059 - val_loss: 0.0134
# Epoch 14/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 15/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0038 - val_loss: 0.0113
# Epoch 16/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0034 - val_loss: 0.0110
# Epoch 17/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0033 - val_loss: 0.0120
# Epoch 18/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0036 - val_loss: 0.0124
# Epoch 19/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0034 - val_loss: 0.0120
# Epoch 20/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0030 - val_loss: 0.0114
# Epoch 21/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0031 - val_loss: 0.0127
# Epoch 22/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0030 - val_loss: 0.0128
# Epoch 23/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0031 - val_loss: 0.0133
# Epoch 24/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0024 - val_loss: 0.0119
# Epoch 25/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0030 - val_loss: 0.0128
# Epoch 26/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0024 - val_loss: 0.0113
# Epoch 27/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0025 - val_loss: 0.0120
# Epoch 28/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0024 - val_loss: 0.0121
# Epoch 29/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0025 - val_loss: 0.0122
# Epoch 30/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0023 - val_loss: 0.0115
# Epoch 31/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0021 - val_loss: 0.0118
# Epoch 32/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0022 - val_loss: 0.0119
# Epoch 33/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0022 - val_loss: 0.0121
# Epoch 34/100
# 7/7 [==============================] - 1s 118ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 35/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0022 - val_loss: 0.0106
# Epoch 36/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0020 - val_loss: 0.0120
# Epoch 37/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0020 - val_loss: 0.0108
# Epoch 38/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0022 - val_loss: 0.0119
# Epoch 39/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0021 - val_loss: 0.0107
# Epoch 40/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0020 - val_loss: 0.0108
# Epoch 41/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0019 - val_loss: 0.0120
# Epoch 42/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0021 - val_loss: 0.0109
# Epoch 43/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0018 - val_loss: 0.0105
# Epoch 44/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0019 - val_loss: 0.0106
# Epoch 45/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0016 - val_loss: 0.0101
# Epoch 46/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0015 - val_loss: 0.0101
# Epoch 47/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0019 - val_loss: 0.0120
# Epoch 48/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0017 - val_loss: 0.0091
# Epoch 49/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0016 - val_loss: 0.0116
# Epoch 50/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0017 - val_loss: 0.0099
# Epoch 51/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0017 - val_loss: 0.0098
# Epoch 52/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0016 - val_loss: 0.0103
# Epoch 53/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0018 - val_loss: 0.0087
# Epoch 54/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0018 - val_loss: 0.0114
# Epoch 55/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0017 - val_loss: 0.0093
# Epoch 56/100
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0016 - val_loss: 0.0103
# Epoch 57/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0015 - val_loss: 0.0091
# Epoch 58/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0015 - val_loss: 0.0094
# Epoch 59/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0016 - val_loss: 0.0096
# Epoch 60/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0015 - val_loss: 0.0096
# Epoch 61/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0014 - val_loss: 0.0093
# Epoch 62/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0017 - val_loss: 0.0096
# Epoch 63/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0016 - val_loss: 0.0095
# Epoch 64/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0014 - val_loss: 0.0089
# Epoch 65/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0015 - val_loss: 0.0093
# Epoch 66/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0014 - val_loss: 0.0088
# Epoch 67/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0015 - val_loss: 0.0085
# Epoch 68/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0017 - val_loss: 0.0103
# Epoch 69/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0015 - val_loss: 0.0084
# Epoch 70/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0014 - val_loss: 0.0091
# Epoch 71/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0086
# Epoch 72/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0013 - val_loss: 0.0088
# Epoch 73/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0012 - val_loss: 0.0087
# Epoch 74/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0012 - val_loss: 0.0086
# Epoch 75/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0013 - val_loss: 0.0091
# Epoch 76/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 77/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0014 - val_loss: 0.0078
# Epoch 78/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0089
# Epoch 79/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0012 - val_loss: 0.0085
# Epoch 80/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0080
# Epoch 81/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0014 - val_loss: 0.0088
# Epoch 82/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0080
# Epoch 83/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0077
# Epoch 84/100
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0013 - val_loss: 0.0078
# Epoch 85/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0011 - val_loss: 0.0082
# Epoch 86/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0012 - val_loss: 0.0078
# Epoch 87/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0012 - val_loss: 0.0081
# Epoch 88/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0014 - val_loss: 0.0085
# Epoch 89/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0011 - val_loss: 0.0078
# Epoch 90/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0011 - val_loss: 0.0079
# Epoch 91/100
# 7/7 [==============================] - 1s 127ms/step - loss: 0.0013 - val_loss: 0.0081
# Epoch 92/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0012 - val_loss: 0.0077
# Epoch 93/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0012 - val_loss: 0.0074
# Epoch 94/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0013 - val_loss: 0.0076
# Epoch 95/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0011 - val_loss: 0.0072
# Epoch 96/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0011 - val_loss: 0.0077
# Epoch 97/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0011 - val_loss: 0.0073
# Epoch 98/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0011 - val_loss: 0.0073
# Epoch 99/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0010 - val_loss: 0.0074
# Epoch 100/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0014 - val_loss: 0.0072
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0072
# 6/6 [==============================] - 1s 13ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 400)            691200
#
#  dropout_2 (Dropout)         (None, 5, 400)            0
#
#  lstm_5 (LSTM)               (None, 400)               1281600
#
#  dense_4 (Dense)             (None, 128)               51328
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 4s 174ms/step - loss: 0.2184 - val_loss: 0.0808
# Epoch 2/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.1063 - val_loss: 0.0548
# Epoch 3/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0853 - val_loss: 0.0477
# Epoch 4/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0656 - val_loss: 0.0249
# Epoch 5/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0459 - val_loss: 0.0156
# Epoch 6/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0336 - val_loss: 0.0133
# Epoch 7/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0249 - val_loss: 0.0145
# Epoch 8/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0192 - val_loss: 0.0131
# Epoch 9/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0141 - val_loss: 0.0100
# Epoch 10/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0086 - val_loss: 0.0072
# Epoch 11/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 12/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 13/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 14/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0030 - val_loss: 0.0071
# Epoch 15/100
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 16/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 17/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0024 - val_loss: 0.0058
# Epoch 18/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 19/100
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0023 - val_loss: 0.0051
# Epoch 20/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 21/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0020 - val_loss: 0.0048
# Epoch 22/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0023 - val_loss: 0.0054
# Epoch 23/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0023 - val_loss: 0.0051
# Epoch 24/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 25/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 26/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0020 - val_loss: 0.0056
# Epoch 27/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 28/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0020 - val_loss: 0.0048
# Epoch 29/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0020 - val_loss: 0.0058
# Epoch 30/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 31/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 32/100
# 7/7 [==============================] - 1s 113ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 33/100
# 7/7 [==============================] - 1s 206ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 34/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 35/100
# 7/7 [==============================] - 1s 156ms/step - loss: 0.0019 - val_loss: 0.0060
# Epoch 36/100
# 7/7 [==============================] - 1s 142ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 37/100
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 38/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 39/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 40/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0021 - val_loss: 0.0064
# Epoch 41/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 42/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 43/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 44/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 45/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 46/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 47/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 48/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 49/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 50/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 51/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 52/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 53/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0018 - val_loss: 0.0061
# Epoch 54/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0014 - val_loss: 0.0052
# Epoch 55/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 56/100
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0014 - val_loss: 0.0049
# Epoch 57/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 58/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 59/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 60/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 61/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 62/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 63/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 64/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 65/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 66/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 67/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 68/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 69/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0014 - val_loss: 0.0063
# Epoch 70/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 71/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 72/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 73/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 74/100
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 75/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 76/100
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 77/100
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 78/100
# 7/7 [==============================] - 1s 144ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 79/100
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 80/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0013 - val_loss: 0.0051
# Epoch 81/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 82/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 83/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 84/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 85/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 86/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 87/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 88/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 89/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 90/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 91/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 92/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 93/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0011 - val_loss: 0.0054
# Epoch 94/100
# 7/7 [==============================] - 1s 84ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 95/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 96/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 97/100
# 7/7 [==============================] - 1s 142ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 98/100
# 7/7 [==============================] - 1s 147ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 99/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 100/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0012 - val_loss: 0.0055
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0055
# 6/6 [==============================] - 1s 13ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 5, 400)            691200
#
#  dropout_3 (Dropout)         (None, 5, 400)            0
#
#  lstm_7 (LSTM)               (None, 400)               1281600
#
#  dense_6 (Dense)             (None, 128)               51328
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 6s 206ms/step - loss: 0.1842 - val_loss: 0.1819
# Epoch 2/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.1015 - val_loss: 0.1240
# Epoch 3/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0709 - val_loss: 0.0981
# Epoch 4/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0473 - val_loss: 0.0707
# Epoch 5/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0281 - val_loss: 0.0497
# Epoch 6/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0185 - val_loss: 0.0394
# Epoch 7/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0156 - val_loss: 0.0364
# Epoch 8/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0129 - val_loss: 0.0328
# Epoch 9/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0115 - val_loss: 0.0287
# Epoch 10/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0091 - val_loss: 0.0267
# Epoch 11/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0085 - val_loss: 0.0252
# Epoch 12/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0065 - val_loss: 0.0215
# Epoch 13/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0061 - val_loss: 0.0201
# Epoch 14/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0055 - val_loss: 0.0176
# Epoch 15/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0045 - val_loss: 0.0161
# Epoch 16/100
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0043 - val_loss: 0.0139
# Epoch 17/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0038 - val_loss: 0.0134
# Epoch 18/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0042 - val_loss: 0.0127
# Epoch 19/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0042 - val_loss: 0.0115
# Epoch 20/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0038 - val_loss: 0.0122
# Epoch 21/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0040 - val_loss: 0.0095
# Epoch 22/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0036 - val_loss: 0.0113
# Epoch 23/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0035 - val_loss: 0.0106
# Epoch 24/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0031 - val_loss: 0.0104
# Epoch 25/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0036 - val_loss: 0.0111
# Epoch 26/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0035 - val_loss: 0.0093
# Epoch 27/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0035 - val_loss: 0.0098
# Epoch 28/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0032 - val_loss: 0.0109
# Epoch 29/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0040 - val_loss: 0.0101
# Epoch 30/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0033 - val_loss: 0.0118
# Epoch 31/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 32/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0035 - val_loss: 0.0104
# Epoch 33/100
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0033 - val_loss: 0.0096
# Epoch 34/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0032 - val_loss: 0.0098
# Epoch 35/100
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 36/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0031 - val_loss: 0.0098
# Epoch 37/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 38/100
# 7/7 [==============================] - 1s 144ms/step - loss: 0.0033 - val_loss: 0.0101
# Epoch 39/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0030 - val_loss: 0.0100
# Epoch 40/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0033 - val_loss: 0.0093
# Epoch 41/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0032 - val_loss: 0.0093
# Epoch 42/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0031 - val_loss: 0.0106
# Epoch 43/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 44/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0030 - val_loss: 0.0108
# Epoch 45/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0029 - val_loss: 0.0098
# Epoch 46/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0030 - val_loss: 0.0103
# Epoch 47/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0030 - val_loss: 0.0107
# Epoch 48/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0029 - val_loss: 0.0098
# Epoch 49/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 50/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0030 - val_loss: 0.0106
# Epoch 51/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0028 - val_loss: 0.0092
# Epoch 52/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0027 - val_loss: 0.0100
# Epoch 53/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0030 - val_loss: 0.0102
# Epoch 54/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 55/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0028 - val_loss: 0.0102
# Epoch 56/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0026 - val_loss: 0.0096
# Epoch 57/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0025 - val_loss: 0.0104
# Epoch 58/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 59/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0027 - val_loss: 0.0100
# Epoch 60/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0028 - val_loss: 0.0093
# Epoch 61/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0027 - val_loss: 0.0090
# Epoch 62/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0024 - val_loss: 0.0098
# Epoch 63/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0025 - val_loss: 0.0094
# Epoch 64/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0028 - val_loss: 0.0095
# Epoch 65/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0029 - val_loss: 0.0090
# Epoch 66/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0027 - val_loss: 0.0087
# Epoch 67/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 68/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0025 - val_loss: 0.0093
# Epoch 69/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0026 - val_loss: 0.0092
# Epoch 70/100
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0025 - val_loss: 0.0093
# Epoch 71/100
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0028 - val_loss: 0.0090
# Epoch 72/100
# 7/7 [==============================] - 1s 144ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 73/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0026 - val_loss: 0.0093
# Epoch 74/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0025 - val_loss: 0.0088
# Epoch 75/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 76/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 77/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0025 - val_loss: 0.0085
# Epoch 78/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 79/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0023 - val_loss: 0.0090
# Epoch 80/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 81/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0025 - val_loss: 0.0086
# Epoch 82/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0023 - val_loss: 0.0081
# Epoch 83/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0024 - val_loss: 0.0090
# Epoch 84/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 85/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0024 - val_loss: 0.0086
# Epoch 86/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0023 - val_loss: 0.0088
# Epoch 87/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0023 - val_loss: 0.0089
# Epoch 88/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 89/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0023 - val_loss: 0.0084
# Epoch 90/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0023 - val_loss: 0.0087
# Epoch 91/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 92/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 93/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0022 - val_loss: 0.0081
# Epoch 94/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0026 - val_loss: 0.0097
# Epoch 95/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.0024 - val_loss: 0.0077
# Epoch 96/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 97/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0022 - val_loss: 0.0079
# Epoch 98/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0022 - val_loss: 0.0086
# Epoch 99/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 100/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0023 - val_loss: 0.0083
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0083
# 6/6 [==============================] - 1s 16ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 5, 400)            691200
#
#  dropout_4 (Dropout)         (None, 5, 400)            0
#
#  lstm_9 (LSTM)               (None, 400)               1281600
#
#  dense_8 (Dense)             (None, 128)               51328
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 5s 251ms/step - loss: 0.1889 - val_loss: 0.1725
# Epoch 2/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.1034 - val_loss: 0.1124
# Epoch 3/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0733 - val_loss: 0.0853
# Epoch 4/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0567 - val_loss: 0.0638
# Epoch 5/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0400 - val_loss: 0.0502
# Epoch 6/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0303 - val_loss: 0.0382
# Epoch 7/100
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0227 - val_loss: 0.0282
# Epoch 8/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0186 - val_loss: 0.0221
# Epoch 9/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0160 - val_loss: 0.0180
# Epoch 10/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0130 - val_loss: 0.0155
# Epoch 11/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0113 - val_loss: 0.0151
# Epoch 12/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0080 - val_loss: 0.0144
# Epoch 13/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0067 - val_loss: 0.0135
# Epoch 14/100
# 7/7 [==============================] - 1s 90ms/step - loss: 0.0059 - val_loss: 0.0132
# Epoch 15/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0056 - val_loss: 0.0130
# Epoch 16/100
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0046 - val_loss: 0.0125
# Epoch 17/100
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 18/100
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0044 - val_loss: 0.0139
# Epoch 19/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0045 - val_loss: 0.0132
# Epoch 20/100
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0048 - val_loss: 0.0135
# Epoch 21/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0037 - val_loss: 0.0119
# Epoch 22/100
# 7/7 [==============================] - 1s 109ms/step - loss: 0.0042 - val_loss: 0.0114
# Epoch 23/100
# ...
# Epoch 58/100
# 7/7 [==============================] - 1s 93ms/step - loss: 8.9839e-04 - val_loss: 0.0021
# Epoch 59/100
# 7/7 [==============================] - 1s 96ms/step - loss: 8.7997e-04 - val_loss: 0.0029
# Epoch 60/100
# 7/7 [==============================] - 1s 93ms/step - loss: 8.4111e-04 - val_loss: 0.0015
# Epoch 61/100
# 7/7 [==============================] - 1s 99ms/step - loss: 8.0389e-04 - val_loss: 0.0014
# Epoch 62/100
# 7/7 [==============================] - 1s 92ms/step - loss: 8.6513e-04 - val_loss: 0.0024
# Epoch 63/100
# 7/7 [==============================] - 1s 92ms/step - loss: 8.5685e-04 - val_loss: 0.0022
# Epoch 64/100
# 7/7 [==============================] - 1s 136ms/step - loss: 9.0384e-04 - val_loss: 0.0017
# Epoch 65/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 66/100
# 7/7 [==============================] - 1s 132ms/step - loss: 9.5328e-04 - val_loss: 0.0012
# Epoch 67/100
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 68/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 69/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 70/100
# 7/7 [==============================] - 1s 90ms/step - loss: 8.7798e-04 - val_loss: 0.0018
# Epoch 71/100
# 7/7 [==============================] - 1s 93ms/step - loss: 8.8713e-04 - val_loss: 0.0011
# Epoch 72/100
# 7/7 [==============================] - 1s 95ms/step - loss: 7.9176e-04 - val_loss: 0.0010
# Epoch 73/100
# 7/7 [==============================] - 1s 90ms/step - loss: 7.4429e-04 - val_loss: 0.0011
# Epoch 74/100
# 7/7 [==============================] - 1s 95ms/step - loss: 7.5851e-04 - val_loss: 0.0012
# Epoch 75/100
# 7/7 [==============================] - 1s 99ms/step - loss: 7.3057e-04 - val_loss: 0.0011
# Epoch 76/100
# 7/7 [==============================] - 1s 95ms/step - loss: 8.4248e-04 - val_loss: 0.0016
# Epoch 77/100
# 7/7 [==============================] - 1s 99ms/step - loss: 8.9647e-04 - val_loss: 0.0013
# Epoch 78/100
# 7/7 [==============================] - 1s 97ms/step - loss: 7.0607e-04 - val_loss: 0.0012
# Epoch 79/100
# 7/7 [==============================] - 1s 99ms/step - loss: 7.2834e-04 - val_loss: 0.0013
# Epoch 80/100
# 7/7 [==============================] - 1s 95ms/step - loss: 8.0655e-04 - val_loss: 0.0015
# Epoch 81/100
# 7/7 [==============================] - 1s 89ms/step - loss: 8.0773e-04 - val_loss: 0.0015
# Epoch 82/100
# 7/7 [==============================] - 1s 91ms/step - loss: 8.4665e-04 - val_loss: 0.0010
# Epoch 83/100
# 7/7 [==============================] - 1s 122ms/step - loss: 8.9034e-04 - val_loss: 0.0010
# Epoch 84/100
# 7/7 [==============================] - 1s 136ms/step - loss: 7.9679e-04 - val_loss: 0.0016
# Epoch 85/100
# 7/7 [==============================] - 1s 137ms/step - loss: 7.1975e-04 - val_loss: 0.0012
# Epoch 86/100
# 7/7 [==============================] - 1s 142ms/step - loss: 6.9285e-04 - val_loss: 0.0014
# Epoch 87/100
# 7/7 [==============================] - 1s 99ms/step - loss: 7.4785e-04 - val_loss: 0.0013
# Epoch 88/100
# 7/7 [==============================] - 1s 92ms/step - loss: 7.5048e-04 - val_loss: 9.4610e-04
# Epoch 89/100
# 7/7 [==============================] - 1s 92ms/step - loss: 8.6486e-04 - val_loss: 0.0011
# Epoch 90/100
# 7/7 [==============================] - 1s 93ms/step - loss: 9.4834e-04 - val_loss: 0.0019
# Epoch 91/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 92/100
# 7/7 [==============================] - 1s 98ms/step - loss: 9.3970e-04 - val_loss: 0.0011
# Epoch 93/100
# 7/7 [==============================] - 1s 95ms/step - loss: 8.1855e-04 - val_loss: 0.0011
# Epoch 94/100
# 7/7 [==============================] - 1s 96ms/step - loss: 7.8529e-04 - val_loss: 0.0011
# Epoch 95/100
# 7/7 [==============================] - 1s 96ms/step - loss: 7.5415e-04 - val_loss: 0.0014
# Epoch 96/100
# 7/7 [==============================] - 1s 95ms/step - loss: 8.6034e-04 - val_loss: 0.0013
# Epoch 97/100
# 7/7 [==============================] - 1s 95ms/step - loss: 7.8488e-04 - val_loss: 0.0010
# Epoch 98/100
# 7/7 [==============================] - 1s 96ms/step - loss: 7.0595e-04 - val_loss: 0.0017
# Epoch 99/100
# 7/7 [==============================] - 1s 93ms/step - loss: 6.6508e-04 - val_loss: 0.0022
# Epoch 100/100
# 7/7 [==============================] - 1s 98ms/step - loss: 8.9824e-04 - val_loss: 0.0015
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0015
# 6/6 [==============================] - 1s 17ms/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 5, 400)            691200
#
#  dropout_11 (Dropout)        (None, 5, 400)            0
#
#  lstm_23 (LSTM)              (None, 400)               1281600
#
#  dense_22 (Dense)            (None, 128)               51328
#
#  dense_23 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 2024257 (7.72 MB)
# Trainable params: 2024257 (7.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 4s 208ms/step - loss: 0.1734 - val_loss: 0.0608
# Epoch 2/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0541 - val_loss: 0.0291
# Epoch 3/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0305 - val_loss: 0.0256
# Epoch 4/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0169 - val_loss: 0.0124
# Epoch 5/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0058 - val_loss: 0.0139
# Epoch 6/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0028 - val_loss: 0.0203
# Epoch 7/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0031 - val_loss: 0.0134
# Epoch 8/100
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0028 - val_loss: 0.0146
# Epoch 9/100
# 7/7 [==============================] - 1s 145ms/step - loss: 0.0027 - val_loss: 0.0149
# Epoch 10/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0026 - val_loss: 0.0110
# Epoch 11/100
# 7/7 [==============================] - 1s 141ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 12/100
# 7/7 [==============================] - 1s 142ms/step - loss: 0.0024 - val_loss: 0.0101
# Epoch 13/100
# 7/7 [==============================] - 1s 108ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 14/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 15/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0022 - val_loss: 0.0116
# Epoch 16/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0022 - val_loss: 0.0151
# Epoch 17/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0024 - val_loss: 0.0140
# Epoch 18/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 19/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0017 - val_loss: 0.0070
# Epoch 20/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0019 - val_loss: 0.0088
# Epoch 21/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0016 - val_loss: 0.0094
# Epoch 22/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0017 - val_loss: 0.0100
# Epoch 23/100
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0017 - val_loss: 0.0091
# Epoch 24/100
# 7/7 [==============================] - 1s 104ms/step - loss: 0.0017 - val_loss: 0.0081
# Epoch 25/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0017 - val_loss: 0.0084
# Epoch 26/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 27/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0017 - val_loss: 0.0072
# Epoch 28/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0016 - val_loss: 0.0073
# Epoch 29/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 30/100
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0013 - val_loss: 0.0084
# Epoch 31/100
# 7/7 [==============================] - 1s 144ms/step - loss: 0.0014 - val_loss: 0.0083
# Epoch 32/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0013 - val_loss: 0.0075
# Epoch 33/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0013 - val_loss: 0.0081
# Epoch 34/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0013 - val_loss: 0.0067
# Epoch 35/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 36/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 37/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0014 - val_loss: 0.0082
# Epoch 38/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0014 - val_loss: 0.0079
# Epoch 39/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0012 - val_loss: 0.0075
# Epoch 40/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 41/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0013 - val_loss: 0.0088
# Epoch 42/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 0.0080
# Epoch 43/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 44/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0013 - val_loss: 0.0070
# Epoch 45/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0012 - val_loss: 0.0060
# Epoch 46/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0011 - val_loss: 0.0062
# Epoch 47/100
# 7/7 [==============================] - 1s 141ms/step - loss: 0.0012 - val_loss: 0.0076
# Epoch 48/100
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0011 - val_loss: 0.0080
# Epoch 49/100
# 7/7 [==============================] - 1s 149ms/step - loss: 0.0012 - val_loss: 0.0063
# Epoch 50/100
# 7/7 [==============================] - 1s 154ms/step - loss: 0.0011 - val_loss: 0.0062
# Epoch 51/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 52/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0012 - val_loss: 0.0060
# Epoch 53/100
# 7/7 [==============================] - 1s 99ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 54/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0013 - val_loss: 0.0091
# Epoch 55/100
# 7/7 [==============================] - 1s 93ms/step - loss: 9.5165e-04 - val_loss: 0.0069
# Epoch 56/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0012 - val_loss: 0.0073
# Epoch 57/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 0.0061
# Epoch 58/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0010 - val_loss: 0.0067
# Epoch 59/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0010 - val_loss: 0.0076
# Epoch 60/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0014 - val_loss: 0.0081
# Epoch 61/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 62/100
# 7/7 [==============================] - 1s 95ms/step - loss: 9.5724e-04 - val_loss: 0.0065
# Epoch 63/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0010 - val_loss: 0.0071
# Epoch 64/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0011 - val_loss: 0.0068
# Epoch 65/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0012 - val_loss: 0.0063
# Epoch 66/100
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 67/100
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 68/100
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0018 - val_loss: 0.0053
# Epoch 69/100
# 7/7 [==============================] - 1s 148ms/step - loss: 0.0014 - val_loss: 0.0099
# Epoch 70/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0011 - val_loss: 0.0064
# Epoch 71/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 72/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0011 - val_loss: 0.0063
# Epoch 73/100
# 7/7 [==============================] - 1s 99ms/step - loss: 9.4987e-04 - val_loss: 0.0066
# Epoch 74/100
# 7/7 [==============================] - 1s 101ms/step - loss: 8.9520e-04 - val_loss: 0.0053
# Epoch 75/100
# 7/7 [==============================] - 1s 99ms/step - loss: 9.0235e-04 - val_loss: 0.0065
# Epoch 76/100
# 7/7 [==============================] - 1s 99ms/step - loss: 9.6640e-04 - val_loss: 0.0063
# Epoch 77/100
# 7/7 [==============================] - 1s 97ms/step - loss: 9.8223e-04 - val_loss: 0.0063
# Epoch 78/100
# 7/7 [==============================] - 1s 105ms/step - loss: 8.9941e-04 - val_loss: 0.0053
# Epoch 79/100
# 7/7 [==============================] - 1s 100ms/step - loss: 9.7369e-04 - val_loss: 0.0061
# Epoch 80/100
# 7/7 [==============================] - 1s 97ms/step - loss: 9.4981e-04 - val_loss: 0.0056
# Epoch 81/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0011 - val_loss: 0.0078
# Epoch 82/100
# 7/7 [==============================] - 1s 96ms/step - loss: 9.9692e-04 - val_loss: 0.0050
# Epoch 83/100
# 7/7 [==============================] - 1s 92ms/step - loss: 8.4770e-04 - val_loss: 0.0067
# Epoch 84/100
# 7/7 [==============================] - 1s 92ms/step - loss: 9.3434e-04 - val_loss: 0.0051
# Epoch 85/100
# 7/7 [==============================] - 1s 114ms/step - loss: 9.0391e-04 - val_loss: 0.0053
# Epoch 86/100
# 7/7 [==============================] - 1s 136ms/step - loss: 9.4030e-04 - val_loss: 0.0069
# Epoch 87/100
# 7/7 [==============================] - 1s 138ms/step - loss: 9.3867e-04 - val_loss: 0.0061
# Epoch 88/100
# 7/7 [==============================] - 1s 141ms/step - loss: 9.0242e-04 - val_loss: 0.0049
# Epoch 89/100
# 7/7 [==============================] - 1s 110ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 90/100
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0011 - val_loss: 0.0075
# Epoch 91/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 92/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0010 - val_loss: 0.0058
# Epoch 93/100
# 7/7 [==============================] - 1s 97ms/step - loss: 9.5104e-04 - val_loss: 0.0055
# Epoch 94/100
# 7/7 [==============================] - 1s 98ms/step - loss: 9.6671e-04 - val_loss: 0.0047
# Epoch 95/100
# 7/7 [==============================] - 1s 94ms/step - loss: 9.3357e-04 - val_loss: 0.0059
# Epoch 96/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 97/100
# 7/7 [==============================] - 1s 99ms/step - loss: 7.7076e-04 - val_loss: 0.0049
# Epoch 98/100
# 7/7 [==============================] - 1s 96ms/step - loss: 8.9616e-04 - val_loss: 0.0063
# Epoch 99/100
# 7/7 [==============================] - 1s 99ms/step - loss: 8.2585e-04 - val_loss: 0.0065
# Epoch 100/100
# 7/7 [==============================] - 1s 92ms/step - loss: 9.2562e-04 - val_loss: 0.0069
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0069
# 6/6 [==============================] - 1s 16ms/step
# New lowest error achieved: 0.04479473829269409
# Learning Rate: 0.0003161185527560565
# Dropout Rate: 0.4081658165816582
# LSTM Activation: tanh
# Dense Activation: relu
