# %% [markdown]
# **MC-LSTM**

# %%
## Run this so that the Orgonal Code can pull and clone the Github repository and install it
# !git clone https://github.com/zexyang/RUL_prediction_ME599.git
# %cd RUL_prediction_ME599
# !cat README.md
# Out:
# Cloning into 'RUL_prediction_ME599'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 51 (delta 13), reused 28 (delta 8), pack-reused 18
# Receiving objects: 100% (51/51), 57.80 MiB | 10.47 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (22/22), done.
# /content/RUL_prediction_ME599
# # A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data
# [![DOI:10.1145/3575882.3575903](http://img.shields.io/badge/DOI-10.1145/3575882.3575903-1481c1.svg)](https://doi.org/10.1145/3575882.3575903)
#
# + Battery RUL prediction using data-driven method based on a hybrid deep model of Convolutional Neural Networks (CNN) and Long-Short Term Memory (LSTM).
# + CNN and LSTM are used to extract features from multiple measurable data (Voltage, Current, Temperature, Capacity) in parallel.
# + CNN extracts features of multi-channel charging profiles, whereas LSTM extracts features of historical capacity data of discharging profiles which related to time dependency.
# + This repository provides the code for training in python.
# ---
# ### Framework:
# ![Contoh Gambar](framework.png)
# + Voltage (V), Current (I), and Temperature (T) inputs will each get in the CNN layer separately.
#   + Feature V gets into a different CNN layer with features I and T, as well as a feature I get into a separate CNN layer with V
#   and T, and so on.
#   + The output from the CNN layer for each feature, is then concatenated. Then they get the next CNN layer
#   + The extracted features in the last CNN layer is concatenated with the output of the LSTM layer.
#
# ### Results
# ![Contoh Gambar](result.png)
#
# | Model        |  RMSE  |   MAE  | MAPE (%) |
# |--------------|:------:|:------:|:--------:|
# | SC-LSTM      | 0,0620 | 0,0549 |  3,6080  |
# | MC-LSTM      | 0,0403 | 0,0340 |  2,2847  |
# | SC-CNN-LSTM  | 0,0270 | 0,0215 |  1,3804  |
# | MC-CNN-LSTM  | 0,0359 | 0,0291 |  1,9346  |
# | MC-SCNN-LSTM | 0,0276 | 0,0220 |  1,4207  |
#
# + SC : Single Channel, MC : Multi Channel
# + The performance of prediction models were compared  using some evaluation metrics
# including root mean square error (RMSE), mean absolute error
# (MAE), and mean absolute percentage error (MAPE).
# + The hybrid model with excellent feature extraction helps to produce more accurate prediction.
# + The MC-SCNNLSTM, MC-CNN-LSTM, and SC-CNN-LSTM model’s prediction results produce predictive values that are close to actual values and are better than the baseline model.
# + Hybrid  of CNN-LSTM model achieves 61%, 37%, and 15% performance
# improvements of MAPE in terms of SC-CNN-LSTM, MC-SCNN-LSTM, and MC-CNN-LSTM respectively, compared to using the single model
#
#
# ### How to Cite
#
# ```
#   @inproceedings{10.1145/3575882.3575903,
#   author = {Hafizhahullah, Huzaifi and Yuliani, Asri Rizki and Pardede, Hilman and Ramdan, Ade and Zilvan, Vicky and Krisnandi, Dikdik and Kadar, Jimmy},
#   title = {A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data},
#   year = {2023},
#   isbn = {9781450397902},
#   publisher = {Association for Computing Machinery},
#   url = {https://doi.org/10.1145/3575882.3575903},
#   doi = {10.1145/3575882.3575903},
#   booktitle = {Proceedings of the 2022 International Conference on Computer, Control, Informatics and Its Applications},
#   pages = {106–110},
#   numpages = {5},
#   keywords = {Lithium-ion battery, remaining useful life, capacity prediction, CNN-LSTM, neural networks},
#   }
# ```

# %%
import random as rn
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.layers import Dense, LSTM, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import json
import re

# Set seeds for reproducibility
SEED = 12345
os.environ["CUDA_VISIBLE_DEVICES"] = str(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
rn.seed(SEED)
tf.compat.v1.random.set_random_seed(SEED)
tf.random.set_seed(SEED)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# Define preprocessing function
def preprocess(dataset):
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(dataset)
    return scaled, scaler

# Define function to extract VIT capacity
def extract_VIT_capacity(x_datasets, y_datasets, seq_len, hop, sample):
    from pandas import read_csv, DataFrame
    V, I, T, C = [], [], [], []
    x, y = [], []

    for x_data, y_data in zip(x_datasets, y_datasets):
        x_df = read_csv(x_data).dropna()[['cycle', 'voltage_battery', 'current_battery', 'temp_battery']]
        x_df = x_df[x_df['cycle'] != 0].reset_index(drop=True)

        y_df = read_csv(y_data).dropna()[['capacity']]
        y_df['cycle_idx'] = y_df.index + 1
        y_df = y_df.astype('float32').values

        data_len = int(np.floor((len(y_df) - seq_len - 1) / hop)) + 1

        for i in range(len(y_df)):
            cy = x_df.cycle.unique()[i]
            df = x_df[x_df['cycle'] == cy]
            cap = np.array([y_df[i, 0]])
            C.append(cap)
            scaled_C, scaler_C = preprocess(np.array(C))
            le = len(df['voltage_battery']) % sample

            vTemp = df['voltage_battery'].to_numpy()
            if (le != 0):
                vTemp = vTemp[0:-le]
            vTemp = np.reshape(vTemp, (len(vTemp) // sample, -1), order="F").mean(axis=0)
            V.append(vTemp)
            scaled_V, _ = preprocess(np.array(V))

            iTemp = df['current_battery'].to_numpy()
            if (le != 0):
                iTemp = iTemp[0:-le]
            iTemp = np.reshape(iTemp, (len(iTemp) // sample, -1), order="F").mean(axis=0)
            I.append(iTemp)
            scaled_I, _ = preprocess(np.array(I))

            tTemp = df['temp_battery'].to_numpy()
            if (le != 0):
                tTemp = tTemp[0:-le]
            tTemp = np.reshape(tTemp, (len(tTemp) // sample, -1), order="F").mean(axis=0)
            T.append(tTemp)
            scaled_T, _ = preprocess(np.array(T))

            VIT_temp = np.concatenate([scaled_V, scaled_I, scaled_T, scaled_C], axis=1)

        for i in range(data_len):
            x.append(VIT_temp[(hop * i):(hop * i + seq_len)])
            y.append(scaled_C[hop * i + seq_len])

    return np.array(x), np.array(y), scaler_C

# Define function to create and train model
def train_evaluate_model(lstm_units, trainX, trainY, valX, valY, testX, testY, seq_len, batch_size, epochs):
    model = Sequential([
        LSTM(lstm_units, input_shape=(seq_len, trainX.shape[-1]), activation='tanh', return_sequences=True),
        Dropout(0.5),
        Flatten(),
        Dense(lstm_units),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    model.summary()

    history = model.fit(trainX, trainY, validation_data=(valX, valY), batch_size=batch_size, epochs=epochs)

    val_results = model.evaluate(valX, valY)
    test_results = model.evaluate(testX, testY)

    valPredict = model.predict(valX)
    testPredict = model.predict(testX)

    return {
        "model": model,
        "history": history,
        "val_loss": val_results,
        "test_loss": test_results,
        "val_predict": valPredict,
        "test_predict": testPredict
    }

# Define main function
def main():
    import RUL_prediction_ME599.train.param_VITC_C as pr
    import RUL_prediction_ME599.train.utils as utils

    pth = pr.pth
    train_x_files = [os.path.join(pth, 'charge/train', f) for f in os.listdir(os.path.join(pth, 'charge/train'))]
    train_x_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    train_y_files = [os.path.join(pth, 'discharge/train', f) for f in os.listdir(os.path.join(pth, 'discharge/train'))]
    train_y_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    test_x_data = [os.path.join(pth, 'charge/test', f) for f in os.listdir(os.path.join(pth, 'charge/test'))]
    test_y_data = [os.path.join(pth, 'discharge/test', f) for f in os.listdir(os.path.join(pth, 'discharge/test'))]

    folds = list(KFold(n_splits=pr.k, shuffle=True, random_state=pr.random).split(train_x_files))

    results = []

    for lstm_units in [32, 400]:
        for j, (train_idx, val_idx) in enumerate(folds):
            print(f'\nFold {j + 1} with {lstm_units} LSTM units')
            train_x_data = [train_x_files[i] for i in train_idx]
            train_y_data = [train_y_files[i] for i in train_idx]
            val_x_data = [train_x_files[i] for i in val_idx]
            val_y_data = [train_y_files[i] for i in val_idx]

            trainX, trainY, SS_tr = extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len, pr.hop, pr.sample)
            valX, valY, SS_val = extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len, pr.hop, pr.sample)
            testX, testY, SS_tt = extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len, pr.hop, pr.sample)

            print('Input shape: {}'.format(trainX.shape))

            result = train_evaluate_model(lstm_units, trainX, trainY, valX, valY, testX, testY, pr.seq_len, pr.batch_size, pr.epochs)

            testPredict = result["test_predict"]
            inv_testY = SS_tt.inverse_transform(testY)
            inv_testPredict = SS_tt.inverse_transform(testPredict)

            test_mae = mean_absolute_error(inv_testY, inv_testPredict)
            test_mse = mean_squared_error(inv_testY, inv_testPredict)
            test_mape = mean_absolute_percentage_error(inv_testY, inv_testPredict)
            test_rmse = np.sqrt(mean_squared_error(inv_testY, inv_testPredict))

            print(f'Test MAE: {test_mae}')
            print(f'Test MSE: {test_mse}')
            print(f'Test MAPE: {test_mape}')
            print(f'Test RMSE: {test_rmse}')

            results.append({
                "lstm_units": lstm_units,
                "fold": j + 1,
                "val_loss": result["val_loss"],
                "test_loss": result["test_loss"],
                "test_mae": test_mae,
                "test_mse": test_mse,
                "test_mape": test_mape,
                "test_rmse": test_rmse
            })

    # Print the results for comparison
    for res in results:
        print(f"LSTM Units: {res['lstm_units']}, Fold: {res['fold']}, Test MAE: {res['test_mae']}, Test MSE: {res['test_mse']}, Test MAPE: {res['test_mape']}, Test RMSE: {res['test_rmse']}")

if __name__ == "__main__":
    main()
# Out:
# Fold 1 with 32 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 5, 32)             8192
#
#  dropout_6 (Dropout)         (None, 5, 32)             0
#
#  flatten_6 (Flatten)         (None, 160)               0
#
#  dense_12 (Dense)            (None, 32)                5152
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 13377 (52.25 KB)
# Trainable params: 13377 (52.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 2s 80ms/step - loss: 0.1512 - val_loss: 0.0708
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0929 - val_loss: 0.0605
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0471 - val_loss: 0.0536
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0357 - val_loss: 0.0335
# Epoch 5/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0266 - val_loss: 0.0377
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0225 - val_loss: 0.0315
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0168 - val_loss: 0.0235
# Epoch 8/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0134 - val_loss: 0.0204
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0205
# Epoch 10/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0104 - val_loss: 0.0158
# Epoch 11/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0187
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0087 - val_loss: 0.0129
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0121
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0127
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0126
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0093
# Epoch 17/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0105
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0115
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0110
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0107
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.0110
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0063 - val_loss: 0.0101
# Epoch 23/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0082
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0118
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0055 - val_loss: 0.0101
# Epoch 26/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0087
# Epoch 27/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0091
# Epoch 28/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0086
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0072
# Epoch 30/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0098
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 32/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0076
# Epoch 33/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0090
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0083
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0080
# Epoch 36/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 37/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0060
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0094
# Epoch 39/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0078
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0082
# Epoch 42/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0073
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0073
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0078
# Epoch 45/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0070
# Epoch 47/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0075
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0078
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0072
# Epoch 50/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 51/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0032 - val_loss: 0.0067
# Epoch 52/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0062
# Epoch 53/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0073
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0073
# Epoch 55/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0077
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0054
# Epoch 59/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0063
# Epoch 60/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0058
# Epoch 61/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0074
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0068
# Epoch 63/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0056
# Epoch 64/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 65/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 66/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 67/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0082
# Epoch 68/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 69/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0059
# Epoch 70/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 71/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 72/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0058
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 74/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 0.0053
# Epoch 75/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 76/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0064
# Epoch 78/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0069
# Epoch 79/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 80/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0055
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 82/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 83/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 84/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 85/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0058
# Epoch 86/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0055
# Epoch 87/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0055
# Epoch 88/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0049
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 90/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 92/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0052
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0062
# Epoch 94/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0044
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0042
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0042
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076
# 6/6 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# Test MAE: 0.03886988386511803
# Test MSE: 0.0020159762352705
# Test MAPE: 0.025644302368164062
# Test RMSE: 0.04489962384104729
#
# Fold 2 with 32 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 5, 32)             8192
#
#  dropout_7 (Dropout)         (None, 5, 32)             0
#
#  flatten_7 (Flatten)         (None, 160)               0
#
#  dense_14 (Dense)            (None, 32)                5152
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 13377 (52.25 KB)
# Trainable params: 13377 (52.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 121ms/step - loss: 0.6042 - val_loss: 0.3040
# Epoch 2/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2556 - val_loss: 0.1121
# Epoch 3/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1145 - val_loss: 0.0428
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0912 - val_loss: 0.0449
# Epoch 5/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0474 - val_loss: 0.0632
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0438 - val_loss: 0.0449
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0377 - val_loss: 0.0427
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0310 - val_loss: 0.0447
# Epoch 9/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0272 - val_loss: 0.0433
# Epoch 10/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0280 - val_loss: 0.0372
# Epoch 11/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0252 - val_loss: 0.0330
# Epoch 12/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0239 - val_loss: 0.0314
# Epoch 13/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0197 - val_loss: 0.0267
# Epoch 14/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0189 - val_loss: 0.0259
# Epoch 15/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0167 - val_loss: 0.0273
# Epoch 16/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0146 - val_loss: 0.0191
# Epoch 17/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0134 - val_loss: 0.0167
# Epoch 18/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0141 - val_loss: 0.0193
# Epoch 19/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0140 - val_loss: 0.0172
# Epoch 20/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0125 - val_loss: 0.0157
# Epoch 21/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0106 - val_loss: 0.0183
# Epoch 22/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0108 - val_loss: 0.0147
# Epoch 23/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0123
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0101 - val_loss: 0.0121
# Epoch 25/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0130
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0148
# Epoch 27/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0091 - val_loss: 0.0117
# Epoch 28/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0091 - val_loss: 0.0131
# Epoch 29/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0081 - val_loss: 0.0131
# Epoch 30/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0127
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0125
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0114
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0116
# Epoch 34/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0108
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0098
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0100
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0092
# Epoch 39/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0135
# Epoch 40/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0107
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0101
# Epoch 42/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0095
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0083
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0097
# Epoch 45/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0087
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0106
# Epoch 47/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0088
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0096
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0063 - val_loss: 0.0088
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0117
# Epoch 51/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0073
# Epoch 52/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0079
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 54/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0086
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0086
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 0.0080
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0060
# Epoch 60/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0069
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0073
# Epoch 63/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 0.0071
# Epoch 64/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0067
# Epoch 65/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 68/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0079
# Epoch 69/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0068
# Epoch 71/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0060
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0080
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 76/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 77/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0071
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 80/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 81/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 84/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 85/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 86/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 88/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 92/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 98/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 100/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0031
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0031
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0084
# 6/6 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# Test MAE: 0.04124988242983818
# Test MSE: 0.002221205737441778
# Test MAPE: 0.02747536264359951
# Test RMSE: 0.04712966829538345
#
# Fold 3 with 32 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 5, 32)             8192
#
#  dropout_8 (Dropout)         (None, 5, 32)             0
#
#  flatten_8 (Flatten)         (None, 160)               0
#
#  dense_16 (Dense)            (None, 32)                5152
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 13377 (52.25 KB)
# Trainable params: 13377 (52.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 2s 85ms/step - loss: 0.2280 - val_loss: 0.0403
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0956 - val_loss: 0.0791
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0772 - val_loss: 0.0251
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0451 - val_loss: 0.0153
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0324 - val_loss: 0.0340
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0257 - val_loss: 0.0307
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0243 - val_loss: 0.0335
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0203 - val_loss: 0.0369
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0186 - val_loss: 0.0381
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0385
# Epoch 11/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0152 - val_loss: 0.0400
# Epoch 12/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0361
# Epoch 13/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0377
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0132 - val_loss: 0.0349
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0363
# Epoch 16/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0121 - val_loss: 0.0400
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0091 - val_loss: 0.0366
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0093 - val_loss: 0.0378
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0377
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0351
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0323
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0357
# Epoch 23/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0306
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0391
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0290
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0306
# Epoch 27/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0285
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0338
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.0276
# Epoch 30/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0317
# Epoch 31/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0230
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0060 - val_loss: 0.0309
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0258
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0238
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0223
# Epoch 36/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0241
# Epoch 37/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0220
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0056 - val_loss: 0.0266
# Epoch 39/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0161
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0229
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0047 - val_loss: 0.0205
# Epoch 42/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0209
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0195
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0220
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0175
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0176
# Epoch 47/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0166
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0196
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0148
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0210
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0178
# Epoch 52/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0157
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0199
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0117
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0041 - val_loss: 0.0179
# Epoch 56/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0140
# Epoch 57/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0147
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0140
# Epoch 59/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0158
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0038 - val_loss: 0.0140
# Epoch 61/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0158
# Epoch 62/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0137
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0123
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0150
# Epoch 65/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0140
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0128
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0141
# Epoch 68/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0103
# Epoch 69/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0165
# Epoch 70/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0097
# Epoch 71/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0149
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0127
# Epoch 73/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0107
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0133
# Epoch 75/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 0.0112
# Epoch 76/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0143
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0107
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0113
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0115
# Epoch 80/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0097
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0032 - val_loss: 0.0121
# Epoch 82/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0119
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0109
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0122
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.0107
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0110
# Epoch 87/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0100
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0122
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0117
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0116
# Epoch 91/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0106
# Epoch 92/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0116
# Epoch 93/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0094
# Epoch 94/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0075
# Epoch 95/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0120
# Epoch 96/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0076
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 0.0095
# Epoch 98/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0111
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0076
# Epoch 100/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0121
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0121
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0064
# 6/6 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# Test MAE: 0.03550102189183235
# Test MSE: 0.00169226189609617
# Test MAPE: 0.02312859706580639
# Test RMSE: 0.04113711044192314
#
# Fold 1 with 400 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 5, 400)            691200
#
#  dropout_9 (Dropout)         (None, 5, 400)            0
#
#  flatten_9 (Flatten)         (None, 2000)              0
#
#  dense_18 (Dense)            (None, 400)               800400
#
#  dense_19 (Dense)            (None, 1)                 401
#
# =================================================================
# Total params: 1492001 (5.69 MB)
# Trainable params: 1492001 (5.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 175ms/step - loss: 1.4688 - val_loss: 0.0446
# Epoch 2/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.2472 - val_loss: 0.1568
# Epoch 3/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1209 - val_loss: 0.1356
# Epoch 4/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0634 - val_loss: 0.0233
# Epoch 5/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0263 - val_loss: 0.0196
# Epoch 6/100
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0125 - val_loss: 0.0127
# Epoch 7/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0095 - val_loss: 0.0071
# Epoch 8/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0069 - val_loss: 0.0101
# Epoch 9/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0058 - val_loss: 0.0084
# Epoch 10/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 11/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 12/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 13/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0047 - val_loss: 0.0062
# Epoch 14/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0043 - val_loss: 0.0064
# Epoch 15/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 16/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 17/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0042 - val_loss: 0.0058
# Epoch 18/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 19/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0039 - val_loss: 0.0062
# Epoch 20/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0039 - val_loss: 0.0062
# Epoch 21/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 22/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0038 - val_loss: 0.0052
# Epoch 23/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0036 - val_loss: 0.0055
# Epoch 24/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0034 - val_loss: 0.0056
# Epoch 25/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 26/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0035 - val_loss: 0.0054
# Epoch 27/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 28/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 29/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0033 - val_loss: 0.0053
# Epoch 30/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 31/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 32/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 33/100
# 7/7 [==============================] - 0s 69ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 34/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 35/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 36/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 37/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 38/100
# 7/7 [==============================] - 1s 82ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 39/100
# 7/7 [==============================] - 1s 71ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 40/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 41/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 42/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 43/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 44/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 45/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 46/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 47/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 48/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0021 - val_loss: 0.0042
# Epoch 49/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 50/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 51/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 52/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 53/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 54/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 55/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 56/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 57/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 58/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 59/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 60/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 61/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 62/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 63/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 64/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 65/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 66/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 67/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 68/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 69/100
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 70/100
# 7/7 [==============================] - 1s 78ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 71/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 72/100
# 7/7 [==============================] - 1s 74ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 73/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 74/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 75/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 76/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 77/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 78/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 79/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 80/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 81/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 82/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 83/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 84/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 85/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 86/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 87/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 88/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 89/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 90/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 91/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 92/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 93/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 94/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 95/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 96/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 97/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 98/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 99/100
# 7/7 [==============================] - 1s 76ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 100/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0016 - val_loss: 0.0026
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0026
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0081
# 6/6 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 11ms/step
# Test MAE: 0.04013783112168312
# Test MSE: 0.0021273584570735693
# Test MAPE: 0.026719117537140846
# Test RMSE: 0.04612329602241516
#
# Fold 2 with 400 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 5, 400)            691200
#
#  dropout_10 (Dropout)        (None, 5, 400)            0
#
#  flatten_10 (Flatten)        (None, 2000)              0
#
#  dense_20 (Dense)            (None, 400)               800400
#
#  dense_21 (Dense)            (None, 1)                 401
#
# =================================================================
# Total params: 1492001 (5.69 MB)
# Trainable params: 1492001 (5.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 4s 144ms/step - loss: 1.8120 - val_loss: 0.0769
# Epoch 2/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.2807 - val_loss: 0.2147
# Epoch 3/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.1545 - val_loss: 0.0187
# Epoch 4/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0746 - val_loss: 0.0061
# Epoch 5/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0388 - val_loss: 0.0629
# Epoch 6/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0190 - val_loss: 0.0258
# Epoch 7/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0128 - val_loss: 0.0081
# Epoch 8/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0107 - val_loss: 0.0074
# Epoch 9/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0062 - val_loss: 0.0136
# Epoch 10/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0052 - val_loss: 0.0088
# Epoch 11/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0054 - val_loss: 0.0090
# Epoch 12/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0048 - val_loss: 0.0083
# Epoch 13/100
# ...
# Epoch 68/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 69/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 70/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 71/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 72/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 73/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 74/100
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 75/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 76/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 77/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 78/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 79/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 80/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 81/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 82/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 83/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 84/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 85/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 86/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 87/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 88/100
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 89/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 90/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 91/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 92/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 93/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 94/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 95/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 96/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 97/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 98/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 99/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 100/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0013 - val_loss: 0.0012
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0012
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0035
# 6/6 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 11ms/step
# Test MAE: 0.023996638134121895
# Test MSE: 0.0009150185505859554
# Test MAPE: 0.01549314334988594
# Test RMSE: 0.030249273404479027
#
# Fold 3 with 400 LSTM units
# Input shape: (326, 5, 31)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 5, 400)            691200
#
#  dropout_11 (Dropout)        (None, 5, 400)            0
#
#  flatten_11 (Flatten)        (None, 2000)              0
#
#  dense_22 (Dense)            (None, 400)               800400
#
#  dense_23 (Dense)            (None, 1)                 401
#
# =================================================================
# Total params: 1492001 (5.69 MB)
# Trainable params: 1492001 (5.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 132ms/step - loss: 1.4206 - val_loss: 0.0186
# Epoch 2/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2357 - val_loss: 0.0812
# Epoch 3/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.1163 - val_loss: 0.0904
# Epoch 4/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0562 - val_loss: 0.0105
# Epoch 5/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0322 - val_loss: 0.0187
# Epoch 6/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 7/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0089 - val_loss: 0.0323
# Epoch 8/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0072 - val_loss: 0.0052
# Epoch 9/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0059 - val_loss: 0.0121
# Epoch 10/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0054 - val_loss: 0.0137
# Epoch 11/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0039 - val_loss: 0.0113
# Epoch 12/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0036 - val_loss: 0.0110
# Epoch 13/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 14/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0041 - val_loss: 0.0130
# Epoch 15/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0033 - val_loss: 0.0103
# Epoch 16/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0036 - val_loss: 0.0105
# Epoch 17/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0032 - val_loss: 0.0096
# Epoch 18/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0031 - val_loss: 0.0100
# Epoch 19/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0030 - val_loss: 0.0079
# Epoch 20/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0031 - val_loss: 0.0095
# Epoch 21/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0029 - val_loss: 0.0093
# Epoch 22/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0033 - val_loss: 0.0087
# Epoch 23/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0029 - val_loss: 0.0080
# Epoch 24/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0028 - val_loss: 0.0082
# Epoch 25/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0030 - val_loss: 0.0086
# Epoch 26/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0030 - val_loss: 0.0077
# Epoch 27/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0027 - val_loss: 0.0069
# Epoch 28/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0073
# Epoch 29/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0024 - val_loss: 0.0072
# Epoch 30/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0025 - val_loss: 0.0077
# Epoch 31/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0023 - val_loss: 0.0078
# Epoch 32/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0026 - val_loss: 0.0066
# Epoch 33/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0027 - val_loss: 0.0073
# Epoch 34/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0025 - val_loss: 0.0071
# Epoch 35/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0025 - val_loss: 0.0081
# Epoch 36/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0021 - val_loss: 0.0060
# Epoch 37/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0022 - val_loss: 0.0096
# Epoch 38/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0020 - val_loss: 0.0061
# Epoch 39/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0022 - val_loss: 0.0070
# Epoch 40/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0022 - val_loss: 0.0087
# Epoch 41/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0027 - val_loss: 0.0054
# Epoch 42/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0020 - val_loss: 0.0075
# Epoch 43/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0022 - val_loss: 0.0074
# Epoch 44/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 45/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0023 - val_loss: 0.0066
# Epoch 46/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0070
# Epoch 47/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 48/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0018 - val_loss: 0.0056
# Epoch 49/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0020 - val_loss: 0.0078
# Epoch 50/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 51/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0019 - val_loss: 0.0084
# Epoch 52/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 53/100
# 7/7 [==============================] - 1s 85ms/step - loss: 0.0017 - val_loss: 0.0062
# Epoch 54/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0021 - val_loss: 0.0067
# Epoch 55/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 56/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 57/100
# 7/7 [==============================] - 1s 88ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 58/100
# 7/7 [==============================] - 1s 70ms/step - loss: 0.0017 - val_loss: 0.0062
# Epoch 59/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 60/100
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 61/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 62/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 63/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0024 - val_loss: 0.0048
# Epoch 64/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 65/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0022 - val_loss: 0.0080
# Epoch 66/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0021 - val_loss: 0.0060
# Epoch 67/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 68/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 69/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0014 - val_loss: 0.0064
# Epoch 70/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 71/100
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 72/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0020 - val_loss: 0.0073
# Epoch 73/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 74/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 75/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 76/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 77/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0017 - val_loss: 0.0054
# Epoch 78/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 79/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 80/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 81/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 82/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 83/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 84/100
# 7/7 [==============================] - 1s 86ms/step - loss: 0.0016 - val_loss: 0.0065
# Epoch 85/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 86/100
# 7/7 [==============================] - 1s 83ms/step - loss: 0.0013 - val_loss: 0.0051
# Epoch 87/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 88/100
# 7/7 [==============================] - 1s 89ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 89/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 90/100
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 91/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0012 - val_loss: 0.0054
# Epoch 92/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 93/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 94/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 95/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 96/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 97/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 98/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 99/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 100/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0011 - val_loss: 0.0054
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0054
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0053
# 6/6 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 13ms/step
# Test MAE: 0.032278429716825485
# Test MSE: 0.0013998554786667228
# Test MAPE: 0.020952727645635605
# Test RMSE: 0.03741464391350746
# LSTM Units: 32, Fold: 1, Test MAE: 0.03886988386511803, Test MSE: 0.0020159762352705, Test MAPE: 0.025644302368164062, Test RMSE: 0.04489962384104729
# LSTM Units: 32, Fold: 2, Test MAE: 0.04124988242983818, Test MSE: 0.002221205737441778, Test MAPE: 0.02747536264359951, Test RMSE: 0.04712966829538345
# LSTM Units: 32, Fold: 3, Test MAE: 0.03550102189183235, Test MSE: 0.00169226189609617, Test MAPE: 0.02312859706580639, Test RMSE: 0.04113711044192314
# LSTM Units: 400, Fold: 1, Test MAE: 0.04013783112168312, Test MSE: 0.0021273584570735693, Test MAPE: 0.026719117537140846, Test RMSE: 0.04612329602241516
# LSTM Units: 400, Fold: 2, Test MAE: 0.023996638134121895, Test MSE: 0.0009150185505859554, Test MAPE: 0.01549314334988594, Test RMSE: 0.030249273404479027
# LSTM Units: 400, Fold: 3, Test MAE: 0.032278429716825485, Test MSE: 0.0013998554786667228, Test MAPE: 0.020952727645635605, Test RMSE: 0.03741464391350746

# %% [markdown]
# MAE (Mean Absolute Error): Measures the average magnitude of errors in a set of predictions, without considering their direction. It gives an idea of how close predictions are to the actual values.
#
#
# MSE (Mean Squared Error): Measures the average of the squares of the errors. It emphasizes larger errors more than MAE because of the squaring, making it useful for understanding large deviations.
#
#
# MAPE (Mean Absolute Percentage Error): Measures the average absolute percentage error, giving a normalized error metric useful for comparing different scales.
#
#
# RMSE (Root Mean Squared Error): The square root of MSE, providing error magnitude in the same unit as the target variable, making it easier to interpret compared to MSE.
#
# 32 Units:
# Consistently higher MAE, MSE, MAPE, and RMSE compared to the 400 units configuration.
# The average metrics suggest that the model with 32 units tends to have larger prediction errors.
#
#
# 400 Units:
# Generally lower error metrics, indicating better predictive performance.
# Fold 2 shows significantly better performance with very low MAE, MSE, and RMSE, suggesting that the model captures the underlying data patterns more effectively with a larger number of LSTM units.
#
# The model with 400 LSTM units outperforms the one with 32 units across most folds, demonstrating lower prediction errors and suggesting better model capacity to learn from the data. The results indicate that increasing the number of LSTM units helps in improving the model's predictive performance, although it might also increase computational requirements.
