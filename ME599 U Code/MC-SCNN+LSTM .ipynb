# %%
## Run this so that the Original Code can pull and clone the Github repository and install it
# !git clone https://github.com/zexyang/RUL_prediction_ME599.git
# %cd RUL_prediction_ME599
# !cat README.md
# Out:
# fatal: destination path 'RUL_prediction_ME599' already exists and is not an empty directory.
# /content/RUL_prediction_ME599/RUL_prediction_ME599
# # A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data
# [![DOI:10.1145/3575882.3575903](http://img.shields.io/badge/DOI-10.1145/3575882.3575903-1481c1.svg)](https://doi.org/10.1145/3575882.3575903)
#
# + Battery RUL prediction using data-driven method based on a hybrid deep model of Convolutional Neural Networks (CNN) and Long-Short Term Memory (LSTM).
# + CNN and LSTM are used to extract features from multiple measurable data (Voltage, Current, Temperature, Capacity) in parallel.
# + CNN extracts features of multi-channel charging profiles, whereas LSTM extracts features of historical capacity data of discharging profiles which related to time dependency.
# + This repository provides the code for training in python.
# ---
# ### Framework:
# ![Contoh Gambar](framework.png)
# + Voltage (V), Current (I), and Temperature (T) inputs will each get in the CNN layer separately.
#   + Feature V gets into a different CNN layer with features I and T, as well as a feature I get into a separate CNN layer with V
#   and T, and so on.
#   + The output from the CNN layer for each feature, is then concatenated. Then they get the next CNN layer
#   + The extracted features in the last CNN layer is concatenated with the output of the LSTM layer.
#
# ### Results
# ![Contoh Gambar](result.png)
#
# | Model        |  RMSE  |   MAE  | MAPE (%) |
# |--------------|:------:|:------:|:--------:|
# | SC-LSTM      | 0,0620 | 0,0549 |  3,6080  |
# | MC-LSTM      | 0,0403 | 0,0340 |  2,2847  |
# | SC-CNN-LSTM  | 0,0270 | 0,0215 |  1,3804  |
# | MC-CNN-LSTM  | 0,0359 | 0,0291 |  1,9346  |
# | MC-SCNN-LSTM | 0,0276 | 0,0220 |  1,4207  |
#
# + SC : Single Channel, MC : Multi Channel
# + The performance of prediction models were compared  using some evaluation metrics
# including root mean square error (RMSE), mean absolute error
# (MAE), and mean absolute percentage error (MAPE).
# + The hybrid model with excellent feature extraction helps to produce more accurate prediction.
# + The MC-SCNNLSTM, MC-CNN-LSTM, and SC-CNN-LSTM model’s prediction results produce predictive values that are close to actual values and are better than the baseline model.
# + Hybrid  of CNN-LSTM model achieves 61%, 37%, and 15% performance
# improvements of MAPE in terms of SC-CNN-LSTM, MC-SCNN-LSTM, and MC-CNN-LSTM respectively, compared to using the single model
#
#
# ### How to Cite
#
# ```
#   @inproceedings{10.1145/3575882.3575903,
#   author = {Hafizhahullah, Huzaifi and Yuliani, Asri Rizki and Pardede, Hilman and Ramdan, Ade and Zilvan, Vicky and Krisnandi, Dikdik and Kadar, Jimmy},
#   title = {A Hybrid CNN-LSTM for Battery Remaining Useful Life Prediction with Charging Profiles Data},
#   year = {2023},
#   isbn = {9781450397902},
#   publisher = {Association for Computing Machinery},
#   url = {https://doi.org/10.1145/3575882.3575903},
#   doi = {10.1145/3575882.3575903},
#   booktitle = {Proceedings of the 2022 International Conference on Computer, Control, Informatics and Its Applications},
#   pages = {106–110},
#   numpages = {5},
#   keywords = {Lithium-ion battery, remaining useful life, capacity prediction, CNN-LSTM, neural networks},
#   }
# ```

# %%
import random as rn
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.layers import Dense, LSTM, Conv1D, Flatten
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import json
import re
import RUL_prediction_ME599.train.param_separated as pr ###Changed from "import param_separated as pr"
import RUL_prediction_ME599.train.utils_new as utils ###Changed from "import utils_new as utils"
import RUL_prediction_ME599.train.utils as utilss ###Changed from "import utils as utilss"


SEED = 12345
os.environ["CUDA_VISIBLE_DEVICES"] = str(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
rn.seed(SEED)
tf.compat.v1.random.set_random_seed(SEED)
tf.random.set_seed(SEED)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)


def main():
    pth = pr.pth
    train_x_files = [os.path.join(pth, 'charge/train', f) for f in os.listdir(os.path.join(pth, 'charge/train'))]
    train_x_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    train_y_files = [os.path.join(pth, 'discharge/train', f) for f in os.listdir(os.path.join(pth, 'discharge/train'))]
    train_y_files.sort(key=lambda f: int(re.sub('\D', '', f)))
    test_x_data = [os.path.join(pth, 'charge/test', f) for f in os.listdir(os.path.join(pth, 'charge/test'))]
    test_y_data = [os.path.join(pth, 'discharge/test', f) for f in os.listdir(os.path.join(pth, 'discharge/test'))]
    print("train X:", train_x_files)
    print("train Y:", train_y_files)

    folds = list(KFold(n_splits=pr.k, shuffle=True, random_state=pr.random, ).split(train_x_files))

    for j, (train_idx, val_idx) in enumerate(folds):
        print('\nFold', j + 1)
        train_x_data = [train_x_files[train_idx[i]] for i in range(len(train_idx))]
        train_y_data = [train_y_files[train_idx[i]] for i in range(len(train_idx))]
        val_x_data = [train_x_files[val_idx[i]] for i in range(len(val_idx))]
        val_y_data = [train_y_files[val_idx[i]] for i in range(len(val_idx))]
        print("train X:", train_x_data)
        print("train y:", train_y_data)
        print("val X:", val_x_data)
        print("val y", val_y_data)
        print("test: x", test_x_data)
        print("test: y", test_y_data)

        # data lstm
        trainX_lstm, trainY_lstm, SS_tr_lstm = utils.extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len_lstm, pr.hop, pr.sample,
                                                                          c=True)
        valX_lstm, valY_lstm, SS_val_lstm = utils.extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len_lstm, pr.hop, pr.sample,
                                                                       c=True)
        testX_lstm, testY_lstm, SS_tt_lstm = utils.extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len_lstm, pr.hop, pr.sample,
                                                                        c=True)
        print('Input shape: {}'.format(trainX_lstm.shape))

        # data cnn (v)
        v_trainX_cnn, v_trainY_cnn, v_SS_tr_cnn = utils.extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                             v=True)
        v_valX_cnn, v_valY_cnn, v_SS_val_cnn = utils.extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                          v=True)
        v_testX_cnn, v_testY_cnn, v_SS_tt_cnn = utils.extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                           v=True)
        print('Input shape: {}'.format(v_trainX_cnn.shape))

        # data cnn (i)
        i_trainX_cnn, i_trainY_cnn, i_SS_tr_cnn = utils.extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                             II=True)
        i_valX_cnn, i_valY_cnn, i_SS_val_cnn = utils.extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                          II=True)
        i_testX_cnn, i_testY_cnn, i_SS_tt_cnn = utils.extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                           II=True)
        print('Input shape: {}'.format(i_trainX_cnn.shape))

        # data cnn (t)
        t_trainX_cnn, t_trainY_cnn, t_SS_tr_cnn = utils.extract_VIT_capacity(train_x_data, train_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                             t=True)
        t_valX_cnn, t_valY_cnn, t_SS_val_cnn = utils.extract_VIT_capacity(val_x_data, val_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                          t=True)
        t_testX_cnn, t_testY_cnn, t_SS_tt_cnn = utils.extract_VIT_capacity(test_x_data, test_y_data, pr.seq_len_cnn, pr.hop, pr.sample,
                                                                           t=True)
        print('Input shape: {}'.format(t_trainX_cnn.shape))

        # define inputs
        input_CNN_v = Input(shape=(pr.seq_len_cnn, v_trainX_cnn.shape[-1]), name="CNN_Input_V")
        input_CNN_i = Input(shape=(pr.seq_len_cnn, i_trainX_cnn.shape[-1]), name="CNN_Input_i")
        input_CNN_t = Input(shape=(pr.seq_len_cnn, t_trainX_cnn.shape[-1]), name="CNN_Input_t")

        input_LSTM = Input(shape=(pr.seq_len_lstm, trainX_lstm.shape[-1]), name="LSTM_Input")

        # define LSTM layer

        LSTM_layer = LSTM(32,
                          activation='tanh',
                          return_sequences=True,
                          name="LSTM_layer")(input_LSTM)

        # define CNN layer

        CNN_layer_v = Conv1D(32, 5, activation='relu',
                             strides=1, padding="same",
                             name="CNN_layer_v")(input_CNN_v)

        CNN_layer_i = Conv1D(32, 5, activation='relu',
                             strides=1, padding="same",
                             name="CNN_layer_i")(input_CNN_i)

        CNN_layer_t = Conv1D(32, 5, activation='relu',
                             strides=1, padding="same",
                             name="CNN_layer_t")(input_CNN_t)

        # fusion CNN
        concat_cnn = concatenate([CNN_layer_v, CNN_layer_i, CNN_layer_t])

        CNN_fusion = Conv1D(32, 5, activation='relu',
                            strides=1, padding='same',
                            name="CNN_fusion")(concat_cnn)

        concat = concatenate([LSTM_layer, CNN_fusion])

        flat = Flatten()(concat)
        output = Dense(32, activation='relu', name="Predictor")(flat)
        output = Dense(1, name="Output")(output)

        model = Model(inputs=[input_LSTM, input_CNN_v, input_CNN_i, input_CNN_t], outputs=[output])

        optim = Adam(learning_rate=pr.lr)
        model.compile(loss='mse', optimizer=optim)

        history = model.fit(x=[trainX_lstm, v_trainX_cnn, i_trainX_cnn, t_trainX_cnn],
                            y=[trainY_lstm, v_trainY_cnn, i_trainY_cnn, t_trainY_cnn],
                            validation_data=([valX_lstm, v_valX_cnn, i_valX_cnn, t_valX_cnn],
                                             [valY_lstm, v_valY_cnn, i_valY_cnn, t_valY_cnn]),
                            batch_size=pr.batch_size,
                            epochs=pr.epochs)

        save_dir = pr.save_dir
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        model_dir = pr.model_dir + '_k' + str(j + 1)
        if not os.path.exists(os.path.join(save_dir, model_dir)):
            os.makedirs(os.path.join(save_dir, model_dir))

        model.save(save_dir + model_dir + "/saved_model_and_weight")
        print("bobot dan model tersimpan")

        # Evaluate on validation and test data
        val_loss = []
        val_results = model.evaluate([valX_lstm, v_valX_cnn, i_valX_cnn, t_valX_cnn],
                                     [valY_lstm, v_valY_cnn, i_valY_cnn, t_valY_cnn])
        val_loss.append(val_results)
        print('Val loss:', val_results)

        test_loss = []
        results = model.evaluate([testX_lstm, v_testX_cnn, i_testX_cnn, t_testX_cnn],
                                 [testY_lstm, v_testY_cnn, i_testY_cnn, t_testY_cnn])
        test_loss.append(results)
        print('Test loss:', results)

        # Prediction
        valPredict = model.predict([valX_lstm, v_valX_cnn, i_valX_cnn, t_valX_cnn])
        testPredict = model.predict([testX_lstm, v_testX_cnn, i_testX_cnn, t_testX_cnn])

        # Inverse transform MinMaxScaler / denormalize
        inv_valY = SS_val_lstm.inverse_transform(v_valY_cnn)
        inv_valPredict = SS_val_lstm.inverse_transform(valPredict)

        inv_testY = SS_tt_lstm.inverse_transform(v_testY_cnn)
        inv_testPredict = SS_tt_lstm.inverse_transform(testPredict)

        # get evaluation metrics ontest data
        test_mae = mean_absolute_error(inv_testY, inv_testPredict)
        test_mse = mean_squared_error(inv_testY, inv_testPredict)
        test_mape = mean_absolute_percentage_error(inv_testY, inv_testPredict)
        test_rmse = np.sqrt(mean_squared_error(inv_testY, inv_testPredict))
        print('\nTest Mean Absolute Error: %f MAE' % test_mae)
        print('Test Mean Square Error: %f MSE' % test_mse)
        print('Test Mean Absolute Percentage Error: %f MAPE' % test_mape)
        print('Test Root Mean Squared Error: %f RMSE' % test_rmse)

        # Save evaluation metrics
        with open(os.path.join(save_dir, model_dir, 'eval_metrics.txt'), 'w') as f:
            f.write('Train data: ')
            f.write(json.dumps(train_x_data))
            f.write('\nVal data: ')
            f.write(json.dumps(val_x_data))
            f.write('\nTest data: ')
            f.write(json.dumps(test_x_data))
            f.write('\n\nTest Mean Absolute Error: ')
            f.write(json.dumps(str(test_mae)))
            f.write('\nTest Mean Square Error: ')
            f.write(json.dumps(str(test_mse)))
            f.write('\nTest Mean Absolute Percentage Error: ')
            f.write(json.dumps(str(test_mape)))
            f.write('\nTest Root Mean Squared Error: ')
            f.write(json.dumps(str(test_rmse)))

        # Save test prediction to text file
        testPred_file = open(os.path.join(save_dir, model_dir, 'test_predict.txt'), 'w')
        for row in inv_testPredict:
            np.savetxt(testPred_file, row)
        testPred_file.close()

        testY_file = open(os.path.join(save_dir, model_dir, 'test_true.txt'), 'w')
        for row in inv_testY:
            np.savetxt(testY_file, row)
        testY_file.close()

        # plot graph
        utilss.plot_loss(history, save_dir, model_dir)
        utilss.plot_pred(inv_valPredict, inv_valY, save_dir, model_dir, "val_pred")
        utilss.plot_pred(inv_testPredict, inv_testY, save_dir, model_dir, "test_pred")


if __name__ == "__main__":
    main()
# Out:
# train X: ['data/NASA/charge/train/B0005_charge.csv', 'data/NASA/charge/train/B0006_charge.csv', 'data/NASA/charge/train/B0007_charge.csv']
# train Y: ['data/NASA/discharge/train/B0005_discharge.csv', 'data/NASA/discharge/train/B0006_discharge.csv', 'data/NASA/discharge/train/B0007_discharge.csv']
#
# Fold 1
# train X: ['data/NASA/charge/train/B0006_charge.csv', 'data/NASA/charge/train/B0007_charge.csv']
# train y: ['data/NASA/discharge/train/B0006_discharge.csv', 'data/NASA/discharge/train/B0007_discharge.csv']
# val X: ['data/NASA/charge/train/B0005_charge.csv']
# val y ['data/NASA/discharge/train/B0005_discharge.csv']
# test: x ['data/NASA/charge/test/B0018_charge.csv']
# test: y ['data/NASA/discharge/test/B0018_discharge.csv']
# Input shape: (326, 5, 1)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Epoch 1/100
# 7/7 [==============================] - 5s 115ms/step - loss: 0.1500 - val_loss: 0.0472
# Epoch 2/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0133 - val_loss: 0.0145
# Epoch 3/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0113
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 5/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 6/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0019 - val_loss: 0.0055
# Epoch 7/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0061
# Epoch 8/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 9/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 10/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0014 - val_loss: 0.0049
# Epoch 11/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 12/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 15/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 16/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 17/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 18/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 19/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 20/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 21/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 22/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0038
# Epoch 23/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0042
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 25/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 26/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0037
# Epoch 28/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 29/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 30/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.7198e-04 - val_loss: 0.0035
# Epoch 31/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.3064e-04 - val_loss: 0.0032
# Epoch 32/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.7040e-04 - val_loss: 0.0037
# Epoch 33/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.3874e-04 - val_loss: 0.0030
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.9258e-04 - val_loss: 0.0031
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8.5272e-04 - val_loss: 0.0029
# Epoch 36/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.2828e-04 - val_loss: 0.0030
# Epoch 37/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.0676e-04 - val_loss: 0.0026
# Epoch 38/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 40/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.7198e-04 - val_loss: 0.0036
# Epoch 41/100
# 7/7 [==============================] - 0s 16ms/step - loss: 9.2735e-04 - val_loss: 0.0029
# Epoch 42/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.0541e-04 - val_loss: 0.0027
# Epoch 43/100
# 7/7 [==============================] - 0s 16ms/step - loss: 9.0524e-04 - val_loss: 0.0029
# Epoch 44/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.0024e-04 - val_loss: 0.0026
# Epoch 45/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.0926e-04 - val_loss: 0.0030
# Epoch 46/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.8996e-04 - val_loss: 0.0036
# Epoch 47/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 48/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.6376e-04 - val_loss: 0.0024
# Epoch 49/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.3163e-04 - val_loss: 0.0027
# Epoch 50/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.9007e-04 - val_loss: 0.0026
# Epoch 51/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.2889e-04 - val_loss: 0.0030
# Epoch 52/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.0241e-04 - val_loss: 0.0035
# Epoch 53/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.6421e-04 - val_loss: 0.0033
# Epoch 54/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 55/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.1696e-04 - val_loss: 0.0025
# Epoch 56/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0026
# Epoch 57/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.9348e-04 - val_loss: 0.0024
# Epoch 58/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.8980e-04 - val_loss: 0.0022
# Epoch 59/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7.7948e-04 - val_loss: 0.0023
# Epoch 60/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.3801e-04 - val_loss: 0.0023
# Epoch 61/100
# 7/7 [==============================] - 0s 17ms/step - loss: 7.7898e-04 - val_loss: 0.0024
# Epoch 62/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.0749e-04 - val_loss: 0.0024
# Epoch 63/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.1958e-04 - val_loss: 0.0024
# Epoch 64/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.8412e-04 - val_loss: 0.0025
# Epoch 65/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.5669e-04 - val_loss: 0.0021
# Epoch 66/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.8094e-04 - val_loss: 0.0033
# Epoch 67/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 68/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.7296e-04 - val_loss: 0.0028
# Epoch 69/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.6457e-04 - val_loss: 0.0017
# Epoch 70/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.1903e-04 - val_loss: 0.0027
# Epoch 71/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8.0882e-04 - val_loss: 0.0020
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6852e-04 - val_loss: 0.0027
# Epoch 73/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.6451e-04 - val_loss: 0.0021
# Epoch 74/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.0221e-04 - val_loss: 0.0027
# Epoch 75/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.6585e-04 - val_loss: 0.0023
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.7188e-04 - val_loss: 0.0025
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.3670e-04 - val_loss: 0.0022
# Epoch 78/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.2619e-04 - val_loss: 0.0021
# Epoch 79/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.2671e-04 - val_loss: 0.0020
# Epoch 80/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.1725e-04 - val_loss: 0.0025
# Epoch 81/100
# 7/7 [==============================] - 0s 17ms/step - loss: 8.6097e-04 - val_loss: 0.0020
# Epoch 82/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.6388e-04 - val_loss: 0.0024
# Epoch 83/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.0858e-04 - val_loss: 0.0019
# Epoch 84/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.8918e-04 - val_loss: 0.0023
# Epoch 85/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.7757e-04 - val_loss: 0.0025
# Epoch 86/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.9757e-04 - val_loss: 0.0022
# Epoch 87/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.2050e-04 - val_loss: 0.0024
# Epoch 88/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.4519e-04 - val_loss: 0.0020
# Epoch 89/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.6202e-04 - val_loss: 0.0020
# Epoch 90/100
# 7/7 [==============================] - 0s 13ms/step - loss: 6.7391e-04 - val_loss: 0.0019
# Epoch 91/100
# 7/7 [==============================] - 0s 23ms/step - loss: 6.5965e-04 - val_loss: 0.0020
# Epoch 92/100
# 7/7 [==============================] - 0s 24ms/step - loss: 8.3467e-04 - val_loss: 0.0019
# Epoch 93/100
# 7/7 [==============================] - 0s 23ms/step - loss: 7.8710e-04 - val_loss: 0.0021
# Epoch 94/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.7318e-04 - val_loss: 0.0023
# Epoch 95/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.5382e-04 - val_loss: 0.0021
# Epoch 96/100
# 7/7 [==============================] - 0s 21ms/step - loss: 8.9223e-04 - val_loss: 0.0023
# Epoch 97/100
# 7/7 [==============================] - 0s 31ms/step - loss: 7.8107e-04 - val_loss: 0.0020
# Epoch 98/100
# 7/7 [==============================] - 0s 23ms/step - loss: 7.6372e-04 - val_loss: 0.0019
# Epoch 99/100
# 7/7 [==============================] - 0s 21ms/step - loss: 7.3831e-04 - val_loss: 0.0024
# Epoch 100/100
# 7/7 [==============================] - 0s 22ms/step - loss: 6.9222e-04 - val_loss: 0.0018
# bobot dan model tersimpan
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0018
# Val loss: 0.001816022559069097
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0055
# Test loss: 0.005453640129417181
# 6/6 [==============================] - 1s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
#
# Test Mean Absolute Error: 0.031761 MAE
# Test Mean Square Error: 0.001441 MSE
# Test Mean Absolute Percentage Error: 0.020376 MAPE
# Test Root Mean Squared Error: 0.037955 RMSE
#
# Fold 2
# train X: ['data/NASA/charge/train/B0005_charge.csv', 'data/NASA/charge/train/B0006_charge.csv']
# train y: ['data/NASA/discharge/train/B0005_discharge.csv', 'data/NASA/discharge/train/B0006_discharge.csv']
# val X: ['data/NASA/charge/train/B0007_charge.csv']
# val y ['data/NASA/discharge/train/B0007_discharge.csv']
# test: x ['data/NASA/charge/test/B0018_charge.csv']
# test: y ['data/NASA/discharge/test/B0018_discharge.csv']
# Input shape: (326, 5, 1)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Epoch 1/100
# 7/7 [==============================] - 5s 186ms/step - loss: 0.0913 - val_loss: 0.0332
# Epoch 2/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0229 - val_loss: 0.0183
# Epoch 3/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 4/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 5/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 6/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 7/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 9/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 10/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 11/100
# 7/7 [==============================] - 0s 15ms/step - loss: 9.1890e-04 - val_loss: 0.0018
# Epoch 12/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.3888e-04 - val_loss: 0.0016
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - loss: 9.2617e-04 - val_loss: 0.0013
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 9.3900e-04 - val_loss: 0.0011
# Epoch 15/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.1314e-04 - val_loss: 0.0011
# Epoch 16/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.3264e-04 - val_loss: 0.0010
# Epoch 17/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.0787e-04 - val_loss: 8.4254e-04
# Epoch 18/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.4663e-04 - val_loss: 9.7589e-04
# Epoch 19/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.0599e-04 - val_loss: 9.0402e-04
# Epoch 20/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.7159e-04 - val_loss: 9.2032e-04
# Epoch 21/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.5188e-04 - val_loss: 9.3057e-04
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.4429e-04 - val_loss: 8.8015e-04
# Epoch 23/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.1723e-04 - val_loss: 9.9344e-04
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.0301e-04 - val_loss: 0.0011
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.6716e-04 - val_loss: 9.1910e-04
# Epoch 26/100
# 7/7 [==============================] - 0s 23ms/step - loss: 5.5079e-04 - val_loss: 7.4506e-04
# Epoch 27/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.6140e-04 - val_loss: 7.8329e-04
# Epoch 28/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.1911e-04 - val_loss: 6.8906e-04
# Epoch 29/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.1688e-04 - val_loss: 7.2929e-04
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 5.1914e-04 - val_loss: 7.1140e-04
# Epoch 31/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0116e-04 - val_loss: 7.8326e-04
# Epoch 32/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1498e-04 - val_loss: 7.2196e-04
# Epoch 33/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9400e-04 - val_loss: 6.9260e-04
# Epoch 34/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.5743e-04 - val_loss: 6.8191e-04
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1744e-04 - val_loss: 6.8664e-04
# Epoch 36/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4.8733e-04 - val_loss: 6.4860e-04
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0540e-04 - val_loss: 6.8114e-04
# Epoch 38/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.3721e-04 - val_loss: 7.2339e-04
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 5.5441e-04 - val_loss: 6.6214e-04
# Epoch 40/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0773e-04 - val_loss: 6.7935e-04
# Epoch 41/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.6217e-04 - val_loss: 6.6501e-04
# Epoch 42/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.1422e-04 - val_loss: 6.1726e-04
# Epoch 43/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.3179e-04 - val_loss: 6.7532e-04
# Epoch 44/100
# 7/7 [==============================] - 0s 13ms/step - loss: 5.1252e-04 - val_loss: 6.0969e-04
# Epoch 45/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.5287e-04 - val_loss: 6.3372e-04
# Epoch 46/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5059e-04 - val_loss: 6.1943e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4624e-04 - val_loss: 6.1434e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3554e-04 - val_loss: 6.3540e-04
# Epoch 49/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5494e-04 - val_loss: 6.4418e-04
# Epoch 50/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6165e-04 - val_loss: 7.0977e-04
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7016e-04 - val_loss: 6.9142e-04
# Epoch 52/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4.4144e-04 - val_loss: 8.1385e-04
# Epoch 53/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0910e-04 - val_loss: 7.5078e-04
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.8396e-04 - val_loss: 6.0265e-04
# Epoch 55/100
# 7/7 [==============================] - 0s 18ms/step - loss: 4.4959e-04 - val_loss: 5.8919e-04
# Epoch 56/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.4162e-04 - val_loss: 6.9149e-04
# Epoch 57/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4317e-04 - val_loss: 6.0346e-04
# Epoch 58/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.5810e-04 - val_loss: 7.1853e-04
# Epoch 59/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.4822e-04 - val_loss: 7.8163e-04
# Epoch 60/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7437e-04 - val_loss: 6.4432e-04
# Epoch 61/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2755e-04 - val_loss: 5.9333e-04
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.4393e-04 - val_loss: 7.0961e-04
# Epoch 63/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.6968e-04 - val_loss: 7.6439e-04
# Epoch 64/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.1243e-04 - val_loss: 8.3544e-04
# Epoch 65/100
# 7/7 [==============================] - 0s 19ms/step - loss: 5.6514e-04 - val_loss: 6.3669e-04
# Epoch 66/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.5790e-04 - val_loss: 6.5202e-04
# Epoch 67/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.1985e-04 - val_loss: 5.9838e-04
# Epoch 68/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.6283e-04 - val_loss: 6.3469e-04
# Epoch 69/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.5339e-04 - val_loss: 6.9525e-04
# Epoch 70/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.2627e-04 - val_loss: 6.6429e-04
# Epoch 71/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.2175e-04 - val_loss: 5.7987e-04
# Epoch 72/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4.1256e-04 - val_loss: 5.8816e-04
# Epoch 73/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.8245e-04 - val_loss: 5.8797e-04
# Epoch 74/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.1214e-04 - val_loss: 6.2847e-04
# Epoch 75/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.1494e-04 - val_loss: 5.8003e-04
# Epoch 76/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.0396e-04 - val_loss: 5.6899e-04
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.8281e-04 - val_loss: 5.6559e-04
# Epoch 78/100
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8617e-04 - val_loss: 6.7255e-04
# Epoch 79/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3947e-04 - val_loss: 7.2685e-04
# Epoch 80/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.1778e-04 - val_loss: 7.0763e-04
# Epoch 81/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.5979e-04 - val_loss: 7.0296e-04
# Epoch 82/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.6378e-04 - val_loss: 6.2893e-04
# Epoch 83/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.0608e-04 - val_loss: 5.7771e-04
# Epoch 84/100
# 7/7 [==============================] - 0s 38ms/step - loss: 3.9938e-04 - val_loss: 5.9824e-04
# Epoch 85/100
# 7/7 [==============================] - 0s 28ms/step - loss: 3.7871e-04 - val_loss: 6.3344e-04
# Epoch 86/100
# 7/7 [==============================] - 0s 18ms/step - loss: 4.2830e-04 - val_loss: 5.8919e-04
# Epoch 87/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.3383e-04 - val_loss: 8.4149e-04
# Epoch 88/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.4032e-04 - val_loss: 5.9069e-04
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 3.8677e-04 - val_loss: 6.0704e-04
# Epoch 90/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.7653e-04 - val_loss: 7.7310e-04
# Epoch 91/100
# 7/7 [==============================] - 0s 44ms/step - loss: 4.8045e-04 - val_loss: 7.8686e-04
# Epoch 92/100
# 7/7 [==============================] - 0s 26ms/step - loss: 5.2590e-04 - val_loss: 5.6324e-04
# Epoch 93/100
# 7/7 [==============================] - 0s 23ms/step - loss: 4.2581e-04 - val_loss: 5.6618e-04
# Epoch 94/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.5559e-04 - val_loss: 5.4776e-04
# Epoch 95/100
# 7/7 [==============================] - 0s 23ms/step - loss: 4.0777e-04 - val_loss: 6.0498e-04
# Epoch 96/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.3538e-04 - val_loss: 5.7080e-04
# Epoch 97/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.2585e-04 - val_loss: 5.5945e-04
# Epoch 98/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.7901e-04 - val_loss: 6.2071e-04
# Epoch 99/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.2595e-04 - val_loss: 6.6418e-04
# Epoch 100/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3.8090e-04 - val_loss: 6.0802e-04
# bobot dan model tersimpan
# 6/6 [==============================] - 0s 4ms/step - loss: 6.0802e-04
# Val loss: 0.0006080199382267892
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0038
# Test loss: 0.003831489710137248
# 6/6 [==============================] - 1s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
#
# Test Mean Absolute Error: 0.023083 MAE
# Test Mean Square Error: 0.001012 MSE
# Test Mean Absolute Percentage Error: 0.014732 MAPE
# Test Root Mean Squared Error: 0.031813 RMSE
#
# Fold 3
# train X: ['data/NASA/charge/train/B0005_charge.csv', 'data/NASA/charge/train/B0007_charge.csv']
# train y: ['data/NASA/discharge/train/B0005_discharge.csv', 'data/NASA/discharge/train/B0007_discharge.csv']
# val X: ['data/NASA/charge/train/B0006_charge.csv']
# val y ['data/NASA/discharge/train/B0006_discharge.csv']
# test: x ['data/NASA/charge/test/B0018_charge.csv']
# test: y ['data/NASA/discharge/test/B0018_discharge.csv']
# Input shape: (326, 5, 1)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Input shape: (326, 5, 10)
# Epoch 1/100
# 7/7 [==============================] - 5s 192ms/step - loss: 0.1086 - val_loss: 0.0133
# Epoch 2/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0160 - val_loss: 0.0293
# Epoch 3/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0058 - val_loss: 0.0098
# Epoch 4/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 0.0106
# Epoch 5/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0012 - val_loss: 0.0097
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 0.0065
# Epoch 7/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8.6467e-04 - val_loss: 0.0061
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.1103e-04 - val_loss: 0.0085
# Epoch 9/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.4706e-04 - val_loss: 0.0084
# Epoch 10/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.5137e-04 - val_loss: 0.0079
# Epoch 11/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.1964e-04 - val_loss: 0.0081
# Epoch 12/100
# 7/7 [==============================] - 0s 17ms/step - loss: 6.8179e-04 - val_loss: 0.0077
# Epoch 13/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.0774e-04 - val_loss: 0.0071
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8621e-04 - val_loss: 0.0062
# Epoch 15/100
# 7/7 [==============================] - 0s 17ms/step - loss: 6.9124e-04 - val_loss: 0.0072
# Epoch 16/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.2936e-04 - val_loss: 0.0084
# Epoch 17/100
# 7/7 [==============================] - 0s 24ms/step - loss: 6.6254e-04 - val_loss: 0.0086
# Epoch 18/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.3304e-04 - val_loss: 0.0059
# Epoch 19/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.5347e-04 - val_loss: 0.0053
# Epoch 20/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.1142e-04 - val_loss: 0.0074
# Epoch 21/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.2547e-04 - val_loss: 0.0088
# Epoch 22/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.9866e-04 - val_loss: 0.0066
# Epoch 23/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.7474e-04 - val_loss: 0.0060
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.4818e-04 - val_loss: 0.0065
# Epoch 25/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.0677e-04 - val_loss: 0.0093
# Epoch 26/100
# 7/7 [==============================] - 0s 16ms/step - loss: 8.0929e-04 - val_loss: 0.0070
# Epoch 27/100
# 7/7 [==============================] - 0s 17ms/step - loss: 8.2929e-04 - val_loss: 0.0059
# Epoch 28/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.6332e-04 - val_loss: 0.0079
# Epoch 29/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.8482e-04 - val_loss: 0.0075
# Epoch 30/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.1720e-04 - val_loss: 0.0056
# Epoch 31/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.3021e-04 - val_loss: 0.0045
# Epoch 32/100
# 7/7 [==============================] - 0s 16ms/step - loss: 7.2172e-04 - val_loss: 0.0065
# Epoch 33/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.1572e-04 - val_loss: 0.0073
# Epoch 34/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.9328e-04 - val_loss: 0.0051
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.0628e-04 - val_loss: 0.0054
# Epoch 36/100
# 7/7 [==============================] - 0s 17ms/step - loss: 6.1565e-04 - val_loss: 0.0070
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.0128e-04 - val_loss: 0.0071
# Epoch 38/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8385e-04 - val_loss: 0.0055
# Epoch 39/100
# 7/7 [==============================] - 0s 15ms/step - loss: 7.4070e-04 - val_loss: 0.0038
# Epoch 40/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.4995e-04 - val_loss: 0.0054
# Epoch 41/100
# 7/7 [==============================] - 0s 19ms/step - loss: 6.6107e-04 - val_loss: 0.0071
# Epoch 42/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.3180e-04 - val_loss: 0.0062
# Epoch 43/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6640e-04 - val_loss: 0.0041
# Epoch 44/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.8345e-04 - val_loss: 0.0063
# Epoch 45/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.3488e-04 - val_loss: 0.0056
# Epoch 46/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.5067e-04 - val_loss: 0.0047
# Epoch 47/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.9678e-04 - val_loss: 0.0050
# Epoch 48/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.4246e-04 - val_loss: 0.0065
# Epoch 49/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.2765e-04 - val_loss: 0.0040
# Epoch 50/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.6663e-04 - val_loss: 0.0058
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.3079e-04 - val_loss: 0.0049
# Epoch 52/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.4360e-04 - val_loss: 0.0047
# Epoch 53/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6062e-04 - val_loss: 0.0042
# Epoch 54/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.4467e-04 - val_loss: 0.0074
# Epoch 55/100
# 7/7 [==============================] - 0s 18ms/step - loss: 5.6882e-04 - val_loss: 0.0054
# Epoch 56/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.3716e-04 - val_loss: 0.0049
# Epoch 57/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.9404e-04 - val_loss: 0.0051
# Epoch 58/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.1987e-04 - val_loss: 0.0063
# Epoch 59/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.2858e-04 - val_loss: 0.0064
# Epoch 60/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.4896e-04 - val_loss: 0.0051
# Epoch 61/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.0121e-04 - val_loss: 0.0045
# Epoch 62/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.7052e-04 - val_loss: 0.0083
# Epoch 63/100
# 7/7 [==============================] - 0s 17ms/step - loss: 7.1701e-04 - val_loss: 0.0053
# Epoch 64/100
# 7/7 [==============================] - 0s 18ms/step - loss: 6.1039e-04 - val_loss: 0.0045
# Epoch 65/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0861e-04 - val_loss: 0.0052
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.4323e-04 - val_loss: 0.0040
# Epoch 67/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.4048e-04 - val_loss: 0.0063
# Epoch 68/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0422e-04 - val_loss: 0.0053
# Epoch 69/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.4872e-04 - val_loss: 0.0046
# Epoch 70/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.8738e-04 - val_loss: 0.0040
# Epoch 71/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.2626e-04 - val_loss: 0.0058
# Epoch 72/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.9679e-04 - val_loss: 0.0048
# Epoch 73/100
# 7/7 [==============================] - 0s 16ms/step - loss: 4.8204e-04 - val_loss: 0.0051
# Epoch 74/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.0215e-04 - val_loss: 0.0043
# Epoch 75/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.1140e-04 - val_loss: 0.0042
# Epoch 76/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.5805e-04 - val_loss: 0.0054
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.4135e-04 - val_loss: 0.0045
# Epoch 78/100
# 7/7 [==============================] - 0s 15ms/step - loss: 4.9891e-04 - val_loss: 0.0053
# Epoch 79/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.3221e-04 - val_loss: 0.0054
# Epoch 80/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.0010e-04 - val_loss: 0.0049
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 5.8430e-04 - val_loss: 0.0056
# Epoch 82/100
# 7/7 [==============================] - 0s 18ms/step - loss: 5.0454e-04 - val_loss: 0.0033
# Epoch 83/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.1301e-04 - val_loss: 0.0069
# Epoch 84/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.9752e-04 - val_loss: 0.0043
# Epoch 85/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.3423e-04 - val_loss: 0.0030
# Epoch 86/100
# 7/7 [==============================] - 0s 17ms/step - loss: 8.2225e-04 - val_loss: 0.0063
# Epoch 87/100
# 7/7 [==============================] - 0s 16ms/step - loss: 6.5359e-04 - val_loss: 0.0036
# Epoch 88/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.5575e-04 - val_loss: 0.0046
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.5679e-04 - val_loss: 0.0058
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.2834e-04 - val_loss: 0.0052
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.3870e-04 - val_loss: 0.0040
# Epoch 92/100
# 7/7 [==============================] - 0s 19ms/step - loss: 6.1330e-04 - val_loss: 0.0033
# Epoch 93/100
# 7/7 [==============================] - 0s 21ms/step - loss: 5.4550e-04 - val_loss: 0.0063
# Epoch 94/100
# 7/7 [==============================] - 0s 17ms/step - loss: 5.2288e-04 - val_loss: 0.0041
# Epoch 95/100
# 7/7 [==============================] - 0s 24ms/step - loss: 5.3084e-04 - val_loss: 0.0044
# Epoch 96/100
# 7/7 [==============================] - 0s 25ms/step - loss: 4.9941e-04 - val_loss: 0.0030
# Epoch 97/100
# 7/7 [==============================] - 0s 23ms/step - loss: 6.7382e-04 - val_loss: 0.0048
# Epoch 98/100
# 7/7 [==============================] - 0s 33ms/step - loss: 7.4659e-04 - val_loss: 0.0051
# Epoch 99/100
# 7/7 [==============================] - 0s 31ms/step - loss: 5.9277e-04 - val_loss: 0.0030
# Epoch 100/100
# 7/7 [==============================] - 0s 24ms/step - loss: 5.8972e-04 - val_loss: 0.0046
# bobot dan model tersimpan
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0046
# Val loss: 0.004553518258035183
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0039
# Test loss: 0.003943144343793392
# 6/6 [==============================] - 1s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
#
# Test Mean Absolute Error: 0.025171 MAE
# Test Mean Square Error: 0.001042 MSE
# Test Mean Absolute Percentage Error: 0.016131 MAPE
# Test Root Mean Squared Error: 0.032273 RMSE
